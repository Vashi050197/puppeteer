# %% [markdown]
# <a href="https://colab.research.google.com/github/Vashi050197/LinkedIn/blob/main/Linkedin_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data={
    "email" : "vashi5684@gmail.com",
    "password" : "(_p8pX94C72(!^_",
    "keywords" : "AI".replace(" ","%20"),
    "location" : "India",
    "phoneNo" : "8077975459"    
}

# %%
print(data)
# app={}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(data)
#       2 # app={}
#
# NameError: name 'data' is not defined

# %%
# !node puppeteer_code.js
# Out:
# 2307.50s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Puppeteer script started...
# Puppeteer script started...
# true
# Puppeteer script started...2
# Puppeteer script started...3
# Puppeteer script started...4
# ^C

# %%
d={}
ques={}

# %%
print(len(ques))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(len(ques))
#
# NameError: name 'ques' is not defined

# %%
class Question:
    def __init__(self,question,answers):
        self.question=question
        self.answers=answers 
    def re(self,ar):
        print(ques) 


question=Question(1,3)
question.re(4)
# Out:
# {}

# %%
# !pip install -q -U google-generativeai

# %%
co={}

# %%
d={}

# %%
g = {}
w = {}
l1 = {}
ic = {}
le = {}
gr = {}
sm = {}
o1 = {}
sf={}
ei={}

# %%
# print(d)
d={'IndusInd Bank': ['https://jigya.co.in/jobs-apprenticeships/indusind-bank/machine-learning-engineer-2?Ref=LinkedIn'], 'Optum': ['https://careers.unitedhealthgroup.com/job/21547768/senior-software-engineer-i-noida-in/?src=JB-22455&utm_source=linkedin.com&utm_medium=job_posting', 'https://uhg.taleo.net/careersection/iam/accessmanagement/login.jsf?lang=en&redirectionURI=https%3A%2F%2Fuhg.taleo.net%2Fcareersection%2F10780%2Fjobapply.ftl%3Fjob%3D2261746%26lang%3Den%26src%3DJB-22455%26utm_source%3Dlinkedin.com%26utm_campaign%3Dundefined%26utm_source%3Dlinkedin.com%26utm_medium%3Djob_posting%26src%3DJB-22455%26_gl%3D1*cpowcy*_gcl_au*MTQ0MjQyMjcwMS4xNzM4OTI0NTAz&TARGET=https%3A%2F%2Fuhg.taleo.net%2Fcareersection%2F10780%2Fjobapply.ftl%3Fjob%3D2261746%26lang%3Den%26src%3DJB-22455%26utm_source%3Dlinkedin.com%26utm_campaign%3Dundefined%26utm_source%3Dlinkedin.com%26utm_medium%3Djob_posting%26src%3DJB-22455%26_gl%3D1*cpowcy*_gcl_au*MTQ0MjQyMjcwMS4xNzM4OTI0NTAz'], 'Sprinklr': ['https://sprinklr.wd1.myworkdayjobs.com/careers/job/India---Haryana---Gurgaon/Machine-Learning-Associate_110166-JOB?source=LinkedIn'], 'Tech Mahindra': ['https://careers.techmahindra.com/JobDetails.aspx?JobCode=NQAAADUAAAA1AAAAMgAAADEAAAA=-P/1+4up0etI='], 'S&P Global': ['https://spgi.wd5.myworkdayjobs.com/en-US/SPGI_Careers/login?redirect=%2Fen-us%2FSPGI_Careers%2Fjob%2FGurgaon-Haryana%2FEngineer--Software-Engineering_305113-1%2Fapply%3Futm_source%3Dlinkedin', 'https://careers.spglobal.com/jobs/305113?lang=en-us&utm_source=linkedin'], 'Policybazaar.com': ['https://docs.google.com/forms/d/e/1FAIpQLSdu3rY890gf61WBABusKcXXk_1O19Y2-_pf4EokJ8vyZc38Bw/viewform'], 'Cache Labs': ['https://forms.clickup.com/42040970/f/182zma-238351/SI31KHCT8K408FCEY6'], 'Cvent': ['https://careers.cvent.com/jobs/5137?lang=en-us&iis=linkedin&iisn=linkedin', 'https://indiacareers-cvent.icims.com/jobs/5137/login?_sp=c519269e-6261-4c9b-ad85-3d8a7d10de67.1738929054616&_jsqid=undefined&iis=linkedin&iisn=linkedin&_ga=2.181160295.198450177.1738929018-1805988294.1738929018&_gl=1*15mkdb3*_ga*MTgwNTk4ODI5NC4xNzM4OTI5MDE4*_ga_5Y2BYGL910*MTczODkyOTAxOC4xLjEuMTczODkyOTA1Mi4yNi4wLjA.'], 'Microsoft': ['https://jobs.careers.microsoft.com/us/en/job/1806511/Software-Engineer?jobsource=linkedin'], 'Ownwell': ['https://boards.greenhouse.io/ownwell/jobs/4441476006?gh_src=c46ff97c6us'], 'Philips': ['https://philips.wd3.myworkdayjobs.com/jobs-and-careers/job/Bangalore/Data-Scientist---AI-for-Computer-Vision_535831/?source=Linkedin', 'https://philips.wd3.myworkdayjobs.com/jobs-and-careers/job/Bangalore/Data-Scientist---AI-for-Computer-Vision_535831//apply?source=Linkedin'], 'Persistent Systems': ['https://careers.persistent.com/jobview/python-developer-india-python-2024101615263950?source=linkedin&medium=PremiumJobPosting'], 'Coursera': ['https://job-boards.greenhouse.io/coursera/jobs/5439396004?gh_src=6d6e4f994us'], 'Roku': ['https://www.weareroku.com/jobs/senior-machine-learning-ai-engineer-bengaluru-karnataka-india?gh_jid=6449029'], "Lowe's India": ['https://lowes.wd5.myworkdayjobs.com/LWS_External_CS/login?redirect=%2FLWS_External_CS%2Fjob%2FBengaluru%2FSoftware-Engineer_JR-02007153-1%2Fapply%3Futm_source%3DLinkedInIndia', 'https://talent.lowes.com/in/en/job/JR-02007153/Software-Engineer?utm_source=LinkedInIndia'], 'Wolters Kluwer': ['https://wk.wd3.myworkdayjobs.com/External/job/Data-Scientist--Python-NLP-SQL-_R0046003/apply?source=LinkedIn_Posting', 'https://wk.wd3.myworkdayjobs.com/External/job/Data-Scientist--Python-NLP-SQL-_R0046003?source=LinkedIn_Posting'], 'Indus Insights': ['https://www.surveymonkey.com/r/MQDMSZG'], 'Niveus Solutions': ['https://career.niveussolutions.com/niveussolutions/jobview/solutions-engineer-ai-data-mangalore-karnataka-india-udupi-karnataka-india-mumbai-maharashtra-india-bangalore-karnataka-india-pune-maharashtra-india-2024081311575386?source=linkedin'], 'PayPal': ['https://paypal.eightfold.ai/careers/job?domain=paypal.com&pid=274904531149&query=R0121124&domain=paypal.com&sort_by=relevance&job_index=0'], 'Kyndryl India': ['https://kyndryl.wd5.myworkdayjobs.com/KyndrylProfessionalCareers/job/Mumbai-Maharashtra-India/Associate--Software-Engineering---Development_R-31783?source=REC_APPLICANT_SOURCE_LinkedIn', 'https://kyndryl.wd5.myworkdayjobs.com/KyndrylProfessionalCareers/login?redirect=%2FKyndrylProfessionalCareers%2Fjob%2FMumbai-Maharashtra-India%2FAssociate--Software-Engineering---Development_R-31783%2Fapply%3Fsource%3DREC_APPLICANT_SOURCE_LinkedIn'], 'Capgemini': ['https://careers.capgemini.com/job/Chennai-%28ex-Madras%29-Machine-Learning-Engineer-B/1154183401/?feedId=388933&utm_source=LinkedInJobPostings', 'https://careers.capgemini.com/job/Chennai-%28ex-Madras%29-Machine-Learning-Engineer-B/1154183401/?feedId=388933&utm_source=LinkedInJobPostings#'], 'TransUnion': ['https://transunion.wd5.myworkdayjobs.com/TransUnion/job/Remote---Pune/Machine-Learning-Engineer_19031298-1?source=LinkedIn', 'https://transunion.wd5.myworkdayjobs.com/TransUnion/job/Remote---Pune/Machine-Learning-Engineer_19031298-1/apply?source=LinkedIn'], 'PwC India': ['https://pwc.wd3.myworkdayjobs.com/Global_Experienced_Careers/job/Mumbai-Shivaji-Park/IN-Senior-Associate--GCP-Developer--Data--Analytics--Advisory---Ahmedabad_572854WD-1/?source=LinkedIn', 'https://pwc.wd3.myworkdayjobs.com/Global_Experienced_Careers/job/Mumbai-Shivaji-Park/IN-Senior-Associate--GCP-Developer--Data--Analytics--Advisory---Ahmedabad_572854WD-1//apply?source=LinkedIn'], 'NetApp': ['https://careers.netapp.com/job/-/-/27600/72833082256?jobPipeline=rd_linkedin&p_sid=QvJZtmb&p_uid=eGYUWTUrUW&ss=paid&utm_campaign=it&utm_content=pj_board&utm_medium=jobad&utm_source=linkedin+slotted', 'https://career4.successfactors.com/careers?company=netappinc'], 'American Express': ['https://aexp.eightfold.ai/careers/job/26865284?hl=en&utm_source=linkedin&domain=aexp.com'], 'Intuit': ['https://jobs.intuit.com/job/-/-/27595/72404290528?cid=job_li_click_in_active-fy20_cn_text_job_intuit-talent&iis=job&iisn=li', 'https://globalcareers-intuit.icims.com/jobs/66776/software-engineer-2/job/login'], 'Janes': ['https://apply.workable.com/janes/j/DACB57437F/apply/'], 'Global Payments Inc.': ['https://jobs.globalpayments.com/en/jobs/r0057973/software-engineer/', 'https://tsys.wd1.myworkdayjobs.com/TSYS/job/Noida-Uttar-Pradesh-India/Software-Engineer_R0057973-1/apply?_ga=2.221891544.1585796047.1738931666-1088507575.1738931666'], 'Boston Consulting Group (BCG)': ['https://careers.bcg.com/global/en/job/BCG1US25791EXTERNALENGLOBAL/AI-Engineer-India-BCG-X?utm_source=linkedin&utm_medium=phenom-feeds&Source+=LinkedIn+Job+Board', 'https://experiencedtalent.bcg.com/candidate/login?domain=bcg.com&hl=en&microsite=microsite_1&utm_source=linkedin&utm_medium=phenom-feeds&next=http%3A%2F%2Fexperiencedtalent.bcg.com%2Fcareerhub%2Fexplore%2Fjobs%2F790296430764%3Fpost_onboarding_pid%3D790296430764%26amp%3Bshow_apply%3D1%26amp%3Bprofile_type%3Dcandidate%26amp%3Bcustomredirect%3D1%26utm_source%3Dlinkedin%26utm_medium%3Dphenom-feeds%26Source%2B%3DLinkedIn%2BJob%2BBoard%26pjid%3D0f65ced0-54c8-4246-96ac-dade98f39c51%26uid%3D194e06a4c96fb6-13c680-6b37-194e06a4c972f55%26p_in_ref%3Dhttps%3A%2F%2Fwww.linkedin.com%2F%26p_lang%3Den_global%26refNum%3DBCG1US'], 'JFrog': ['https://join.jfrog.com/job/6544980-automation-engineer/?gh_src=526d35e41us'], 'CSC': ['https://hczw.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1001/job/11049?utm_medium=jobshare&utm_medium=jobboard&utm_source=linkedin'], 'Analog Devices': ['https://analogdevices.wd1.myworkdayjobs.com/External/job/India-Bangalore-Mantri/Data-Analyst-Data-Scientist---Intern_R243836', 'https://analogdevices.wd1.myworkdayjobs.com/External/login?redirect=%2FExternal%2Fjob%2FIndia-Bangalore-Mantri%2FData-Analyst-Data-Scientist---Intern_R243836%2Fapply'], 'Postman': ['https://job-boards.greenhouse.io/postman/jobs/6083517003?gh_src=7ad26f843us'], 'Dell Technologies': ['https://jobs.dell.com/en/job/-/-/375/77048246224?source=rd_linkedin_job_posting&utm_source=linkedin.com&utm_medium=job_posting&utm_campaign=India&utm_content=social_media&utm_term=366838391&ss=paid', 'https://dell.wd1.myworkdayjobs.com/External/login?redirect=%2FExternal%2Fjob%2FBangalore-India%2FSoftware-Engineer-1_R262067-1%2Fapply%3Futm_campaign%3DIndia%26utm_medium%3Djob_posting%26utm_content%3Dsocial_media%26utm_source%3Dlinkedin.com%26utm_term%3D366838391%26source%3Drd_linkedin_job_posting%26ss%3Dpaid'], 'Cresta': ['https://job-boards.greenhouse.io/cresta/jobs/4517778008?gh_src=9a5432008us'], 'CenTrak': ['https://halma.wd3.myworkdayjobs.com/Halma/job/Halma-India----Bengaluru_PSN-Crescent-3/Lead--Software_JR24_000409/apply?source=LinkedIn'], 'Kantar': ['https://kantar.wd3.myworkdayjobs.com/KANTAR/job/Bangalore-Prestige-Technology-Park/Software-Engineer_R088229-1?source=LinkedIn'], 'PhonePe': ['https://boards.greenhouse.io/embed/job_app?token=5812165003&gh_src=961e65dc3us&source=LinkedIn']}

# %%
print(len(g))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(len(g))
#
# NameError: name 'g' is not defined

# %%
# print(g,w,i1,l1,ic,le,gr ,sm,o1,sf,ei)
z=[g,w,l1,ic,le,gr ,sm,o1,sf,ei]

# %%
# for i in z:
#     print(i)


g={'PhonePe': 'https://boards.greenhouse.io/embed/job_app?token=5812165003&gh_src=961e65dc3us&source=LinkedIn', 'CData Software': 'https://boards.greenhouse.io/cdataindia/jobs/4502150007?gh_jid=4502150007', 'LivePerson': 'https://boards.greenhouse.io/liveperson/jobs/6480708&gh_src=fc870eec1?gh_src=fc870eec1', 'Nethermind': 'https://job-boards.eu.greenhouse.io/nethermind/jobs/4532989101?gh_src=357da232teu', 'Coursera': 'https://job-boards.greenhouse.io/coursera/jobs/5439368004?gh_src=6d6e4f994us'}
w={'CenTrak': 'https://halma.wd3.myworkdayjobs.com/Halma/job/Halma-India----Bengaluru_PSN-Crescent-3/Lead--Software_JR24_000409/apply?source=LinkedIn', 'Kantar': 'https://kantar.wd3.myworkdayjobs.com/KANTAR/job/Bangalore-Prestige-Technology-Park/Software-Engineer_R088229-1?source=LinkedIn', 'Fractal': 'https://fractal.wd1.myworkdayjobs.com/Careers/job/Mumbai/AI-Research-Scientist_SR-24156-1?source=LinkedIn', 'BlackRock': 'https://blackrock.wd1.myworkdayjobs.com/BlackRock_Professional/job/Mumbai-India/Associate---Python-Developer--Finance-Platform-Strategies-_R246697/apply', 'Guidewire Software': 'https://guidewire.wd5.myworkdayjobs.com/external/job/India---Bangalore/Associate-Security-Analyst_JR_12364?source=LinkedIn', 'dentsu': 'https://dentsuaegis.wd3.myworkdayjobs.com/DAN_GLOBAL/job/Mumbai/Research-Analyst_R1082970?source=LinkedIn', 'Nike': 'https://nike.wd1.myworkdayjobs.com/nke/login?redirect=%2Fnke%2Fjob%2FKarnataka-India%2FSr-Manager-Software-Engineering--ITC_R-52075%2Fapply%3Fsource%3DBY_LinkedIn_OrganicFeed%26utm_source%3DBY_LinkedIn_OrganicFeed', 'NXP Semiconductors': 'https://nxp.wd3.myworkdayjobs.com/careers/job/Noida/DFT-Engineer_R-10057283?source=LinkedIn', 'Synechron': 'https://synechron.wd1.myworkdayjobs.com/SynechronCareers/job/Chennai---Taramani-Ascendas/Associate-Specialist-AI-ML_JR1022927?source=LinkedIn', 'S&P Global': 'https://spgi.wd5.myworkdayjobs.com/en-US/SPGI_Careers/login?redirect=%2Fen-us%2FSPGI_Careers%2Fjob%2FGurgaon-Haryana%2FSoftware-Engineer_307597-1%2Fapply%3Futm_source%3Dlinkedin', 'NCR Voyix': 'https://ncr.wd1.myworkdayjobs.com/ext_apac/job/GURGAON-IND/Software-Engineering-Manager--Data-Engineering-_R0149417?source=Applicant-Facing_LinkedIn'}
l1={}
ic={'Blackhawk Network India': 'https://apac-blackhawknetwork.icims.com/jobs/23204/sr.-software-engineer/login?mobile=false&width=659&height=500&bga=true&needsRedirect=false&jan1offset=330&jun1offset=330', 'Docusign': 'https://indiacareers-docusign.icims.com/jobs/25908/login?_sp=b93efa2c-581c-46b3-a36f-3f757d29fb53.1739252761869&_jsqid=undefined&iis=Job+board&iisn=LinkedIn&mobile=true&width=300&height=500&bga=true&needsRedirect=false&jan1offset=330&jun1offset=330'}
le={'Spotify': 'https://jobs.lever.co/spotify/389966a4-8137-4f37-b379-a6744ec59fea?lever-source=LinkedInJobs', 'BPM LLP': 'https://jobs.lever.co/bpmcpa/f58dea16-7200-44b2-9abe-9e7e7dd28e2d/apply?source=LinkedIn'}
gr={}
sm={}
o1={'CSC': 'https://hczw.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1001/job/10246?utm_medium=jobshare&utm_medium=jobboard&utm_source=linkedin', 'Birdeye': 'https://recruiting.paylocity.com/Recruiting/Jobs/Apply/2501256', 'KPMG': 'https://ejgk.fa.em2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_3', 'Volvo Cars': 'https://jobs.volvocars.com/job/Bengaluru-Software-Engineer-KA-562122/1139383501/#', 'InstaAstro': 'https://internshala.com/job/detail/software-developer-backend-job-in-noida-at-instaastro1739171964/', 'Mercedes-Benz Research and Development India': 'https://jobs.mercedes-benz.com/en/tech-lead-for-topic-nerd-142762-MER0003D6N', 'Spyne': 'https://spyneai.keka.com/careers/jobdetails/41721', 'INDmoney': 'https://docs.google.com/forms/d/e/1FAIpQLSdQJiK_vBZgQhj-dpJPW_AbPrgMl2_kQEskiBzgf9mor0Qk8w/viewform?pli=1', 'Crowe Horwath IT Services LLP': 'https://careers.crowe.com/apply?jobSeqNo=CROCROUSR47118EXTERNALENUS&utm_source=linkedin&utm_medium=phenom-feeds&step=1&stepname=personalInformation', 'Soul AI': 'https://app.soulhq.ai/?utm_medium=software_developer_ai_trainer&utm_source=linkedIn&utm_campaign=10-02-25&utm_id=pune', 'Probo': 'https://probo.hire.trakstar.com/jobs/fk0pzkd?pjb_hash=Y7bAmjMPq4', 'ANS Commerce': 'https://cutshort.io/job/Software-Engineer-Gurgaon-Noida-ANS-Digital-Pvt-Ltd-YiFxSE99?utm_source=linkedin-feed&utm_medium=xml&utm_content=job-posting&applicationsource=linkedin-feed', 'Mphasis': 'https://mphasis.ripplehire.com/candidate/?token=zc3UbazOJlmk2NsjRNur&lang=en&source=LINKEDINCAMPAIGN&ref=LINKEDINCAMPAIGN#detail', 'algoleap': 'https://careers.algoleap.com/jobs/Careers/660523000025307127?source=Linkedin', 'Vujis': 'https://docs.google.com/forms/d/e/1FAIpQLSe4OZoUU857vLAbm8j9enooYetW83Xk2reuVK3lZ53kU8lmdA/viewform', 'Takeda': 'https://jobs.takeda.com/job/-/-/1113/77229720864?source=tmp_takeda_linkedin_jobads&utm_source=linkedin.com&utm_medium=job_posting&utm_campaign=Enterprise&utm_content=social_media&utm_term=283784093&ss=paid', 'Google': 'https://www.google.com/about/careers/applications/jobs/results/112457986714018502-video-specialist/?src=Online/LinkedIn/linkedin_us&utm_source=linkedin&utm_medium=jobposting&utm_campaign=contract', 'Truevision.ai': 'https://docs.google.com/forms/d/e/1FAIpQLScvNp7MzAP2egAmiTRXaTLqkOS3pcAnHnxyswKgDmpRbn41aw/viewform', 'Amicon': 'https://cutshort.io/job/Senior-Software-Engineer-NCR-Delhi-Gurgaon-Noida-Amicon-ApegN4cZ?utm_source=linkedin-feed&utm_medium=xml&utm_content=job-posting&applicationsource=linkedin-feed', 'OMP': 'https://careers.omp.com/apply?job=4091490101&title=Quality+Assurance+Test+Engineer+-+Senior+(IN-Mumbai)&location=India-Mumbai', 'CivilCops (Now DolphinChat)': 'https://cutshort.io/job/Python-Developer-Gurugram-DolphinChat-UtSD2l5H?utm_source=linkedin-feed&utm_medium=xml&utm_content=job-posting&applicationsource=linkedin-feed', 'Amdocs': 'https://jobs.amdocs.com/careers?location=Meerut%2C%20Uttar%20Pradesh%2C%20IN&recommended=1', 'Park+': 'https://docs.google.com/forms/d/15RMR7UTbZoLGx1rS3XWZI9d2YRKf1B1mF3dwvcLXe9w/viewform?edit_requested=true', 'Elevation Capital': 'https://apply.workable.com/elevation-capital-3/j/242429D558/apply/?success', 'Larsen & Toubro': 'https://larsentoubrocareers.peoplestrong.com/job/detail/LNT_GA-LD_1215241', 'Saint-Gobain International IT Delivery Centre': 'https://jigya.co.in/jobs-apprenticeships/saint-gobain-indec/senior-mlops-engineer?Ref=LinkedIn', 'Dario': 'https://www.dariohealth.com/thank-you/?position_uid=4C.D42', 'Zycus': 'https://zycus.sensehq.com/careers/jobs/56786?utm_source=LINKEDIN&utm_medium=SOCIAL_MEDIA', 'McCain Foods': 'https://careers.mccain.com/us/en/apply?jobSeqNo=MFOMFBUS34280EXTERNALENUS&utm_source=linkedin&utm_medium=phenom-feeds&step=5&stepname=EEO', 'Checkbox': 'https://www.hirist.tech/j/ai-engineer-deep-learning-medical-imaging-1432612.html?utm_source=LinkedIn&utm_medium=referral&utm_campaign=linkedin_apply&ref=linkedin', 'Quarks': 'https://cutshort.io/job/Backend-Developer-Hyderabad-Quarks-Technosoft-Pvt-Ltd-YkAfyG4t?utm_source=linkedin-feed&utm_medium=xml&utm_content=job-posting&applicationsource=linkedin-feed', 'CynLr': 'https://www.cynlr.com/careers?jobUrl=/jobs/software-engineering-roles#application-form', 'Cisco': 'https://jobs.cisco.com/jobs/Success?projectId=1433270&source=LinkedIn', 'UST': 'https://usource.ripplehire.com/candidate/?token=8YxWjpwDhdL62DFYUIcQ&lang=en&source=USTLINKEDIN&ref=USTLINKEDIN#apply/job/30650', 'Optum': 'https://careers.unitedhealthgroup.com/job/21561950/manager-data-scientist-machine-learning-ai-python-hyderabad-in/?src=JB-22455&utm_source=linkedin.com&utm_medium=job_posting', 'FLYCATCH': 'https://docs.google.com/forms/d/e/1FAIpQLSeij4opl5WSILz9kv363jl2r-bAF_TldT5HCd6ENW0N5uSsvw/viewform', 'Sprouts.ai': 'https://cutshort.io/job/Software-Developer-Backend-Bengaluru-Bangalore-Hyderabad-SproutsAI-wu79YLXI?utm_source=linkedin-feed&utm_medium=xml&utm_content=job-posting&applicationsource=linkedin-feed', 'Acuity Knowledge Partners': 'https://acuitykp.darwinbox.com/ms/candidate/candidate/login?redirect=%2Fms%2Fcandidate%2Fcareers%2Fa67a9f3a4b3bd4___apply%3D1', 'MDA Edge': 'https://www1.jobdiva.com/portal/?a=0xjdnwe7mdf9bjdcrprtwgxidtyqq109fbyx636svshwn20bwotd64qv8l75vc1a&compid=0&source=LinkedIn#/jobs/29515176?jobtitle=Senior%20MLOps%20Engineer', 'Mirra Health Care': 'https://airtable.com/appwx08jlD7vDiZBK/shrqqGNMfnifCvDFf'}
sf={'Capgemini': 'https://career5.successfactors.eu/careers?company=capgemitecP3'}
ei={}

# g={'PhonePe': 'https://boards.greenhouse.io/embed/job_app?token=5812165003&gh_src=961e65dc3us&source=LinkedIn', 'CData Software': 'https://boards.greenhouse.io/cdataindia/jobs/4502150007?gh_jid=4502150007'}
# w={'CenTrak': 'https://halma.wd3.myworkdayjobs.com/Halma/job/Halma-India----Bengaluru_PSN-Crescent-3/Lead--Software_JR24_000409/apply?source=LinkedIn', 'Kantar': 'https://kantar.wd3.myworkdayjobs.com/KANTAR/job/Bangalore-Prestige-Technology-Park/Software-Engineer_R088229-1?source=LinkedIn', 'Fractal': 'https://fractal.wd1.myworkdayjobs.com/Careers/job/Mumbai/AI-Research-Scientist_SR-24156-1?source=LinkedIn', 'BlackRock': 'https://blackrock.wd1.myworkdayjobs.com/BlackRock_Professional/job/Mumbai-India/Associate---Python-Developer--Finance-Platform-Strategies-_R246697/apply', 'Guidewire Software': 'https://guidewire.wd5.myworkdayjobs.com/external/job/India---Bangalore/Associate-Security-Analyst_JR_12364?source=LinkedIn'}
# l1={}
# ic={}
# le={'Spotify': 'https://jobs.lever.co/spotify/389966a4-8137-4f37-b379-a6744ec59fea?lever-source=LinkedInJobs'}
# gr={}
# sm={}
# o1={'CSC': 'https://hczw.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1001/job/10246?utm_medium=jobshare&utm_medium=jobboard&utm_source=linkedin', 'Birdeye': 'https://recruiting.paylocity.com/Recruiting/Jobs/Apply/2501256', 'KPMG': 'https://ejgk.fa.em2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_3', 'Volvo Cars': 'https://jobs.volvocars.com/job/Bengaluru-Software-Engineer-KA-562122/1139383501/#'}
# sf={'Capgemini': 'https://career5.successfactors.eu/careers?company=capgemitecP3'}
# ei={}

# %%
for i in z:
    print(len(i))
# print(len(g))
# Out:
# 5
# 12
# 0
# 3
# 2
# 0
# 0
# 48
# 1
# 0

# %%
## import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
# import subprocess
import time
import google.generativeai as genai

# import enum
import typing_extensions as typing
import google.generativeai as genai

genai.configure(api_key="AIzaSyDEl4vJaneM22pSs67ygDmi9nUTZ87I0xY")

class EasyApplyLinkedin:

    def __init__(self, data):
        """Parameter initialization"""
       
        self.email = data['email']
        self.password = data['password']
        self.keywords = data['keywords']
        self.location = data['location']
        self.options = webdriver.ChromeOptions()
        self.options.debugger_address = "localhost:9222"  # Opens Chrome in remote debugging mode
        self.job_id = ""
        # driver = webdriver.Chrome(options=self.options)
        self.driver = webdriver.Chrome(options=self.options)
        self.phone = data['phoneNo']
        self.puppeteer_script_path = "puppeteer_code.js"
        self.mod = genai.GenerativeModel(
            model_name="gemini-2.0-flash"
            # pro-exp-02-05"
            # "gemini-2.0-flash"
                            )
        self.model = genai.GenerativeModel(
            model_name="gemini-2.0-flash",
            system_instruction="Give the output in 1 word(in Integer format) only, if no answer is found in dictionary than output 9 and RESPONSE ASAP sometime answer is not in dictionary So simply output 9. some of the question has NOTICE PERIOD or NP and 'how soon you can join' these all are same. similarly for current salary,  current CTC or CCTC are same. CCTC is just short form of current CTC. Same Expected CTC and ECTC. ECTC and CCTC are obviously different. Related question which has same meaning/context may be find in the dictionary than answer that but if you are not sure than output 9"
                            )
    
    def login_linkedin(self):

        LINK="https://www.linkedin.com/login"
        
        # LINK = "https://www.linkedin.com/jobs/search/?currentJobId=3765114095&distance=25&f_AL=true&geoId=102713980" + f"&keywords={self.keywords}" + "&origin=JOBS_HOME_SEARCH_CARDS"
        # driver = webdriver.Chrome()

        
        self.driver.get(LINK)
      
        # sign_in = self.driver.find_element(By.XPATH, "./html/body/div[1]/header/nav/div/a[2]")
        # sign_in.click()
        time.sleep(5)
        username = self.driver.find_element(By.ID, "username")
        a=username.get_attribute("value")
        print(a)
        username.send_keys(self.email)
        
        time.sleep(3)
        password = self.driver.find_element(By.ID, "password")
        password.send_keys(self.password)
        time.sleep(2)
        sign_in_button = self.driver.find_element(By.CSS_SELECTOR, ".login__form_action_container  button")
        sign_in_button.click()
        time.sleep(2)

        LINK = "https://www.linkedin.com/jobs/collections/recommended/?currentJobId=4125810851&discover=recommended&discoveryOrigin=JOBS_HOME_JYMBII"
        # driver = webdriver.Chrome()
        self.driver.get(LINK)
        easy_apply = '?f_AL=true&f_WT=2&geoId=92000000'
        # driver.get('https://www.linkedin.com/jobs/search/'+ easy_apply +'&keywords='+ self.keywords +'&location=' + self.location)
        # job_link = self.driver.get('https://www.linkedin.com/jobs/search/'+ easy_apply +'&keywords='+ self.keywords +'&location=' + self.location)
        
        time.sleep(3)
      

    
    def filter(self):
        """This function filters all the job results by 'Easy Apply'"""

        # select all filters, click on Easy Apply, and apply the filter
        all_filters_button = self.driver.find_element(By.XPATH, "//button[@data-control-name='all_filters']")
        all_filters_button.click()
        time.sleep(1)
        easy_apply_button = self.driver.find_element(By.XPATH, "//label[@for='f_AL']")
        easy_apply_button.click()
        time.sleep(2)
        apply_filter_button = self.driver.find_element(By.XPATH, "//button[@data-control-name='all_filters_apply']")
        apply_filter_button.click()


    def submit_apply(self,job_add):
        """This function submits the application for the job add found"""

        print('You are applying to the position of: ', job_add.text)
        job_add.click()
        time.sleep(2)
        

        questi = "Is '" + self.job_id + "' a 'staffing' company? If it is related to IT company or finance company, or any other sector company other than staffing than answer false."

        # Load the samplesmall.mp3 file into a Python Blob object containing the audio
        # file's bytes and then pass the prompt and the audio to Gemini.
        respo = self.mod.generate_content(
            questi,
            generation_config=genai.GenerationConfig(
                                        response_mime_type="application/json", response_schema=bool,temperature=0.0,
                                    ),

        )
        # click on the easy apply button, skip if already applied to the position
        if ( "false" in respo.text) :
            o=input()
            
            if o=="":
                print("q" + "mean " + "You have not Applied before")
                time.sleep(2)
                in_apply = self.driver.find_element(By.XPATH,"//button[@data-job-id]")
                in_apply.click()
            elif o=="w":
                appb=self.driver.find_element(By.CLASS_NAME,"jobs-apply-button--top-card")    
                appb.click()
                a1=input()
                window_handles = self.driver.window_handles
                d[self.job_id]=[]
                a=0
                while(len(window_handles) > 1):
                    
                    if a==0:
                        for i in range(len(window_handles)):
                            zc=window_handles[i+1]
                            self.driver.switch_to.window(zc)
                            current_page = self.driver.current_url
                            url=current_page
                            d[self.job_id].append(current_page) 
                            break # Index -1 gets the last element
                    else:
                        zc=window_handles[-1]
                        self.driver.switch_to.window(zc)
                        current_page = self.driver.current_url
                        d[self.job_id].append(current_page)


                    url=current_page
                    if a==0:
                        # workable
                        # oraclecloud
                        if "greenhouse" in url:
                            g[self.job_id] = url
                            # !node  gr1.js
                            while(True):
                                cq=input()
                                if cq=="1":
                                    # !node gr2.js 
                                elif cq=="2":
                                    # !node gr3.js
                                else:
                                    break     # Store using job_id as key
                        elif "workday" in url or "wd" in url:
                            w[self.job_id] = url
                            while(True):
                                cq=input()
                                if cq=="1":
                                    # !node puppet.js
                                elif cq=="2":
                                    # !node wd.js    
                                elif cq=="3":
                                    self.driver.get(url)      
                                elif cq=="4":
                                    # !node w.js
                                elif cq=="s":
                                    # !node qw.cjs    
                                elif cq=="5":
                                    # !node wd1.js
                                elif cq=="6": 
                                    # !node wdd.js
                                elif cq=="7":
                                    # !node wd1.js
                                    c=input()
                                    if c=="":
                                        # !node wq.js
                                        c1=input()
                                        if c1=="":
                                            # !node c.js
                                elif cq=="":
                                    # !node wd1.js
                                    r=input()
                                    if r=="":
                                        # !node c.js 
                                elif cq=="9":
                                    # !node wds.js
                                elif cq=="r":
                                    # !node c.js           
                                else:
                                    break
                                     
                        elif "successfactors" in url:
                            sf[self.job_id] = url
                        elif "eightfold" in url:
                            ei[self.job_id] = url      
                        elif "taleo" in url:
                            l1[self.job_id] = url
                        elif "icims" in url:
                            ic[self.job_id] = url
                        elif "lever" in url:
                            le[self.job_id] = url
                        elif "smartrecruiters" in url:
                            sm[self.job_id] = url
                        else:
                            o1[self.job_id] = url
                        a=1    
                    self.driver.close()
                    window_handles = self.driver.window_handles
                # g=input()
                # Now you are in the new tab.  Perform actions here.
                # print(driver.title) # Example: Print the title of the new tab
                # driver.find_element(By.ID, "some_element_in_new_tab").send_keys("Some text") # Interact with new tab

                # Close the new tab (optional)
                

                # Switch back to the original tab
                self.driver.switch_to.window(window_handles[0])
                return 
            else:
                print("A " + "mean " + "Already Applied")
                time.sleep(2)
                print('You already applied to this job, go to next...')
                return

            # print('Loop break')
            time.sleep(1)
            r=(input())

            #Case for applications2
            if r=="w":
                self.quick_apply()
                time.sleep(1)
                        
            elif r=="":
                self.quick_apply_next()
                time.sleep(1)
            else:    
                self.discard_method()
                time.sleep(1)
    def scroll_shim(self):
        len_of_page = self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight); var lenOfPage = document.body.scrollHeight; return lenOfPage;")
        match = False
        while not match:
            last_count = len_of_page
            time.sleep(3)
            len_of_page = self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight); var lenOfPage = document.body.scrollHeight; return lenOfPage;")
            if last_count == len_of_page:
                match = True


    def find_offer1(self):
        """This function finds all the offers through all the pages result of the search and filter"""

        # Define a list to store applied job IDs
        # applied_job_ids = []

        time.sleep(3)
        # find the total amount of results (if the results are above 24-more than one page-, we will scroll through all available pages)
        total_results = self.driver.find_element(By.CLASS_NAME, "display-flex.t-12.t-black--light.t-normal")
        total_results_int = int(total_results.text.split(' ', 1)[0].replace(",", ""))
        print("total result: ",total_results_int)

        # ...

        time.sleep(2)
        # get results for the first page
        current_page = self.driver.current_url

        results = self.driver.find_elements(By.CLASS_NAME,"scaffold-layout__list ")
                                            # "tgYTqqxjZFuKlqbGpPfQustvBjkGUguQKmZH")
                                                           # ember-view   NYmFjYtQyamlAQjDjwXvcULhIoZdkGrsabLKU occludable-update p0 relative scaffold-layout__list-item
        # for each job add, submits application if no questions asked

        # for each job add, submits application if no questions asked
        for result in results:
            self.scroll_shim()
            time.sleep(2)

            try:
                hover = ActionChains(self.driver).move_to_element(result)
                hover.perform()
                time.sleep(1)
                titles = result.find_elements(By.CLASS_NAME, 'full-width.artdeco-entity-lockup__title.ember-view')
                comps=result.find_elements(By.CLASS_NAME,'artdeco-entity-lockup__subtitle.ember-view')
                i=0
                for title in titles:                          
                    # job_id = title.get_attribute("data-occludable-job-id")
                    # print(job_id,"hhhhhhhhhh")
                    j=0
                    for comp in comps:
                    # Check if the job ID is already in the applied_job_ids list
                        if i==j:
                            self.job_id=comp.text.strip()
                            break
                        j+=1    
                    i+=1
                    if self.job_id not in co:
                        job_title = title.text.strip()
                        # job_id = title.find_element(By.CSS_SELECTOR, 'a').get_attribute("data-control-id")
                        time.sleep(1)
                        # m=self.driver.current_url
                        print("==========================================")
                        print("")
                        print('Job Title:', job_title, )
                        # print('Job ID:', job_id)
                        time.sleep(1)
                        # d[m]=1
                        # print('Job Title:', title.text)
                        # print('Job ID:', job_id)

                        # Add the job ID to the applied_job_ids list
                        co[self.job_id]="a"
                        
                        com = "Is " +self.job_id+ " a well known company and have good strength of employee more than 200?"

                        # Load the samplesmall.mp3 file into a Python Blob object containing the audio
                        # file's bytes and then pass the prompt and the audio to Gemini.
                        response1 = self.mod.generate_content(
                            com,
                            generation_config=genai.GenerationConfig(
                                                        response_mime_type="application/json", response_schema=bool,temperature=0.0,
                                                    ),

                        )
                        # )
                        print(response1.text)
                        if "true" in response1.text:        
                            self.submit_apply(title)
                        else:
                            continue
                    else:
                        continue            
            except (StaleElementReferenceException, MoveTargetOutOfBoundsException):
                pass

        # ...

        # go through all available pages and job offers and apply
        for page_number in range(25, total_results_int + 25, 25):
            self.driver.get(current_page + '&start=' + str(page_number))
            time.sleep(3)
            results_ext = self.driver.find_elements(By.CLASS_NAME, "scaffold-layout__list ")
                                                    # "ember-view.jobs-search-results__list-item.occludable-update.p0.relative")

            for result_ext in results_ext:
                self.scroll_shim()
                time.sleep(2)
                try:
                    hover_ext = ActionChains(self.driver).move_to_element(result_ext)
                    hover_ext.perform()
                    time.sleep(1)
                    titles_ext = result_ext.find_elements(By.CLASS_NAME, 'full-width.artdeco-entity-lockup__title.ember-view')
                    comps_ext=result_ext.find_elements(By.CLASS_NAME,'artdeco-entity-lockup__subtitle.ember-view')
                    i=0
                    for title in titles_ext:                          
                        # job_id = title.get_attribute("data-occludable-job-id")
                        # print(job_id,"hhhhhhhhhh")
                        j=0
                        for comp in comps_ext:
                        # Check if the job ID is already in the applied_job_ids list
                            if i==j:
                                self.job_id=comp.text.strip()
                                break
                            j+=1    
                        i+=1
                        if self.job_id not in co:
                            job_title = title.text.strip()
                            # job_id = title.find_element(By.CSS_SELECTOR, 'a').get_attribute("data-control-id")
                            time.sleep(1)
                            # m=self.driver.current_url
                            print("==========================================")
                            print("")
                            print('Job Title:', job_title, )
                            # print('Job ID:', job_id)
                            time.sleep(1)
                            # d[m]=1
                            # print('Job Title:', title.text)
                            # print('Job ID:', job_id)

                            # Add the job ID to the applied_job_ids list
                            co[self.job_id]="a"

                            com = "Is " +self.job_id+ " a well known company and have good strength of employee more than 200?"

                            # Load the samplesmall.mp3 file into a Python Blob object containing the audio
                            # file's bytes and then pass the prompt and the audio to Gemini.
                            response1 = self.mod.generate_content(
                                com,
                                generation_config=genai.GenerationConfig(
                                                            response_mime_type="application/json", response_schema=bool,temperature=0.0
                                                        ),

                            )
                            # )
                            print(response1.text)
                            if response1.text== "true":

                                self.submit_apply(title)
                            else:
                                continue
                        else:
                            continue
                except (StaleElementReferenceException, MoveTargetOutOfBoundsException):
                    pass

        else:
            self.close_session()


    def discard_method(self):
        #Does not have quick application
        try:
            discard = self.driver.find_element(By.XPATH,"//button[@data-test-modal-close-btn]")
            discard.send_keys(Keys.RETURN)
            time.sleep(1)
            discard_confirm = self.driver.find_element(By.XPATH,"//button[@data-test-dialog-secondary-btn]")
            discard_confirm.send_keys(Keys.RETURN)
            time.sleep(1)
            print('Not direct application, going to next...')
        except (NoSuchElementException, StaleElementReferenceException, MoveTargetOutOfBoundsException):
            return
    #case 1: Submit
    def quick_apply(self):
        # try to submit if submit application is available...
        #quick_apply


        try:
            # self.scroll_shim();
            # unfollow = self.driver.find_element(By.XPATH,"//input[@id='follow-company-checkbox']")
            # if unfollow.is_selected():
            #     #uncheck
            #     self.driver.execute_script("arguments[0].click();",unfollow)
            time.sleep(1)
            submit = self.driver.find_element(By.XPATH,"//button[@aria-label='Submit application']")
            submit.click()
            time.sleep(1)
            print('Your application is successful...')
            app[self.job_id]="a"
        except (NoSuchElementException, StaleElementReferenceException, MoveTargetOutOfBoundsException):
            print('hoooo')
            return    

        try:
            time.sleep(1)
            done_button = self.driver.find_element(By.XPATH,"//button[@id]")
            done_button.click()
            time.sleep(1)

        except (NoSuchElementException, StaleElementReferenceException, MoveTargetOutOfBoundsException):
            discard_applied = self.driver.find_element(By.XPATH,"//button[@data-test-modal-close-btn]")
            discard_applied.send_keys(Keys.RETURN)
            time.sleep(1)
        
        

    time.sleep(1)
    #case 2: Submit+Next
    def quick_apply_next(self):
        # try to submit if submit application is available...
        #quick_apply_next
        time.sleep(1)
        try:
            

            # !node  puppeteer_code.js

            while(True):
                d=input()
                if d=='a': # Next Button
                    
                    next_button = self.driver.find_element(By.CLASS_NAME, "artdeco-button.artdeco-button--2.artdeco-button--primary.ember-view")
                    next_button.click()
                    
                elif d=='': # Review Button
                     
                    time.sleep(1)
                    # Question_section
                    Question_Label = self.driver.find_elements(By.CSS_SELECTOR,".artdeco-text-input .artdeco-text-input--label")
                    labels = []
                    for label in Question_Label:
                        labels.append(label.text)
                
                    answer = self.driver.find_elements(By.CSS_SELECTOR, ".artdeco-text-input .artdeco-text-input--input, .artdeco-text-input .artdeco-text-input--input:required:invalid, .artdeco-text-input .artdeco-text-input--input:required:valid, .artdeco-text-input .artdeco-text-input--search, .artdeco-text-input .artdeco-text-input--search:required:invalid, .artdeco-text-input .artdeco-text-input--search:required:valid")
                    index = 0
                    pr="Use this Dictionary schema: " + str(ques) + " and answer the question."
                    for ans in answer:
                        r=ans.get_attribute("value")
                        if r!="":
                            continue
                        p=pr +labels[index]
                        result = self.model.generate_content(
                            p,
                            generation_config=genai.GenerationConfig(

                                response_mime_type="application/json", response_schema=int
                            ),
                        )


                        if "9" in result.text:
                            a=input()
                            ques[labels[index]]=a 
                            ans.send_keys(a)
                        else:
                            ans.send_keys(result.text)
                        index += 1
                
                    
                    ad=input()
                    
                    time.sleep(1)
                    review_button = self.driver.find_element(By.CLASS_NAME, "artdeco-button.artdeco-button--2.artdeco-button--primary.ember-view")
                    review_button.click()

                    time.sleep(1)
                    submit_button = self.driver.find_element(By.CLASS_NAME, "artdeco-button.artdeco-button--2.artdeco-button--primary.ember-view")
                    submit_button.click()
                    time.sleep(2)
                    app[self.job_id] = "a"
                    print('Next option selected, your application is successful...')
                    break
                else:
                    time.sleep(1)
                    submit_button = self.driver.find_element(By.CLASS_NAME, "artdeco-button.artdeco-button--2.artdeco-button--primary.ember-view")
                    submit_button.click()
                    time.sleep(2)
                    print('Next option selected, your application is successful...')
                    break

            
        
            
            # try:
            #     p=input()
            #     time.sleep(1)
            try:
                time.sleep(1)
                done_button = self.driver.find_element(By.XPATH,"//button[@id]")
                done_button.click()
                time.sleep(1)

       
            except (NoSuchElementException, StaleElementReferenceException, MoveTargetOutOfBoundsException):
       
                discard_applied_next = self.driver.find_element(By.XPATH,"//button[@data-test-modal-close-btn]")
                discard_applied_next.send_keys(Keys.RETURN)
                time.sleep(1)
        
        except (NoSuchElementException,StaleElementReferenceException, MoveTargetOutOfBoundsException):
            pass
            # result = subprocess.run(
            #     ["node", self.puppeteer_script_path],  # Use the class-level path
            #     capture_output=True,
            #     text=True
            # )
            
           
            # try:
            #     done_button_next = self.driver.find_element(By.XPATH,"//button[@id]")
            #     done_button_next.click()
            #     time.sleep(1)

            # except (NoSuchElementException, StaleElementReferenceException, MoveTargetOutOfBoundsException):
            #     discard_applied_next = self.driver.find_element(By.XPATH,"//button[@data-test-modal-close-btn]")
            #     discard_applied_next.send_keys(Keys.RETURN)
            #     time.sleep(1)

        except (NoSuchElementException,StaleElementReferenceException, MoveTargetOutOfBoundsException):
            pass
    def close_session(self):
        """This function closes the actual session"""

        print('End of the session, see you later!')
        self.driver.close()


    def apply(self):
        """Apply to job offers"""
        #week
        # LINK="https://www.linkedin.com/jobs/search/?currentJobId=4168029466&f_TPR=r86400&geoId=102713980&keywords=software"+" developer&origin=JOB_SEARCH_PAGE_KEYWORD_AUTOCOMPLETE&refresh=true"
        # LINK="https://www.linkedin.com/jobs/search/?currentJobId=4154361815&f_TPR=r604800&geoId=102713980&keywords=Software&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true"
        # "https://www.linkedin.com/jobs/search/?currentJobId=4144699636&f_TPR=r604800&geoId=102713980&keywords=python&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true"
        # py24
        # LINK="https://www.linkedin.com/jobs/search/?currentJobId=4165421868&f_TPR=r86400&geoId=102713980&keywords=Data&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true"
        # LINK="https://www.linkedin.com/jobs/search/?currentJobId=4149148450&f_TPR=r86400&geoId=102713980&keywords=python&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true"
        #esy 
        
        # LINK = "https://www.linkedin.com/jobs/search/?currentJobId=4148250852&f_AL=true&f_TPR=r86400&geoId=102713980&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true&sortBy=R&spellCorrectionEnabled=true"
        #24
        LINK = "https://www.linkedin.com/jobs/search/?currentJobId=4142719778&f_TPR=r86400&geoId=102713980&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true"
        # LINK = "https://www.linkedin.com/jobs/search/?currentJobId=4143173276&f_AL=true&f_TPR=r86400&geoId=102713980&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true"
        # LINK = "https://www.linkedin.com/jobs/search/?currentJobId=3765114095&distance=25&f_AL=true&geoId=102713980" + f"&keywords={self.keywords}" + "&origin=JOBS_HOME_SEARCH_CARDS"
        # driver = webdriver.Chrome()
        self.driver.get(LINK)
        # self.login_linkedin()
        time.sleep(2)
  
        
        # time.sleep(2)

        # time.sleep(2)
        self.find_offer1()
        time.sleep(2)
        self.close_session()

if __name__ == '__main__':


    bot = EasyApplyLinkedin(data)
    bot.apply()
# Out:
# total result:  57928
# ...
#
# Job Title: Partnerships Manager
# Partnerships Manager
# true
# You are applying to the position of:  Partnerships Manager
# Partnerships Manager
# A mean Already Applied
# You already applied to this job, go to next...
# ...
#
# Job Title: Associate Creative Director- Art
# Associate Creative Director- Art
# true
# You are applying to the position of:  Associate Creative Director- Art
# Associate Creative Director- Art
# A mean Already Applied
# You already applied to this job, go to next...
# ...
#
# Job Title: Software Engineer
# Software Engineer with verification
# true
# You are applying to the position of:  Software Engineer
# Software Engineer with verification
# ...
#
# Job Title: Python Developer
# Python Developer with verification
# true
# You are applying to the position of:  Python Developer
# Python Developer with verification
# ...
#
# Job Title: AI Specialist - India
# AI Specialist - India with verification
# true
# ...

# %%
questi = "Is " + "Internkaksha IT Solutions" + " a well known company?"
# Load the samplesmall.mp3 file into a Python Blob object containing the audio
# file's bytes and then pass the prompt and the audio to Gemini.
response = model.generate_content(
    questi,
    generation_config=genai.GenerationConfig(
                                response_mime_type="application/json", response_schema=bool
                            ),

)
print(response.text)
# Out:
# false

# %%
model = genai.GenerativeModel(
            model_name="gemini-2.0-flash"
                            )

# %%
ques={'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Years of work experience with data structures and algorithms': '4', 'Years of experience in Microservices or Application development': '3', 'Years of experience on Dev-Sec-Ops principles and practices': '3', 'Years of work experience with state-of-the-art Generative AI models': '3', 'Years of work experience with ML infrastructure': '3', 'Years of experience in a technical leadership role': '3', 'Years of work experience with JavaScript': '3', 'Years of work experience with React.js': '1', 'Years of work experience with Large Language Model Operations (LLMOps)': '2', 'Years of experience as a Data Science Engineer': '3', 'Years of experience with Mongo DB': '3', 'Years of experience working on DS ALGORITHMS': '5', 'Years of experience in Data Engineering': '4', 'Years of experience with AzureML/AzureAI or GCP Vertex AI': '3', 'Years of experience in production ready Python code development': '5', 'Years of experience in Azure Databricks': '3', 'How soon can you join?': '30', 'Years of work experience with C++': '3', 'Years of work experience with Tableau': '3', 'Years of work experience with Transformer Models': '3', 'Years of work experience with Applied Machine Learning': '5', 'Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)': '3', 'Years of work experience with PySpark': '3', 'Years of work experience with XML': '4', 'Years of full-time experience': '5', 'Years of work experience with Django REST Framework': '3', 'Years of work experience with System Architecture': '3', 'Years of work experience with Data Structures': '4', 'Years of work experience with Apache Spark': '1', 'Years of work experience with Scala': '4', 'Relevant Experience in MLOPS': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '4', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5', 'We must fill this position urgently. Can you start immediately? Please mention your Notice Period In days': '14', 'How many years of work experience do you have with Amazon S3?': '3', 'How many years of work experience do you have with AIML?': '14', 'How many years of Consulting experience do you currently have?': '1', 'How many years of work experience do you have with DevOps?': '3', 'Years of experience in NLP and Deep Leaning?': '3', 'How many years of work experience do you have with Data Science?': '3', 'How many years of experience do you have working directly with LLMs or NLP models?': '3', 'How many years of experience do you have with Python for Computer Vision tasks?': '14', 'How many years of work experience do you have with Chatbot Development?': '2', 'How many years of work experience do you have with Databases?': '4', 'How many years of work experience do you have with AI/ML?': '3', 'How many years of work experience do you have with Deep Learning?': '3', 'What is your Whatsapp number?': '8077975459', 'How many years of work experience do you have with UiPath?': '3', 'How many years of work experience do you have with Django?': '3', 'How many years of work experience do you have with Java?': '2', 'How many years of work experience do you have with Design Patterns?': '3', 'How many years of experience do you have in Azure Data Factory': '2', 'How many years of experience do you have in Azure Kubernetes Service': '2', 'How many years of experience do you have in Python, R, or C#?': '4', 'How many years of work experience do you have with Azure Synapse Analytics': '2', 'How many years of work experience do you have with AWS SageMaker?': '3', 'Current CTC (Enter full number)': '14', 'Do you have any offers in Hand? If yes mention the number': '1', 'How many years of work experience do you have with Data Analytics?': '3', 'How many years of work experience do you have with Database Management System (DBMS)?': '4'}
# print(ques)

# %%
co={'MobiusEngine': 'a', 'Quidich Innovation Labs': 'a', 'YellowSquash': 'a', 'ChainThat Limited': 'a', 'QuillBot': 'a', 'Impetus': 'a', 'BeGig': 'a', 'tsworks': 'a', 'GlobalPros': 'a', 'iMerit Technology': 'a', 'Storable India': 'a', 'People Tech Group Inc': 'a', 'LENS Corporation': 'a', 'TrueFan': 'a', 'Crimson Energy Experts Pvt Ltd': 'a', 'Adept Global': 'a', 'Bellurbis': 'a', 'YO IT CONSULTING': 'a', 'XpertDox': 'a', 'MindBrain': 'a', 'CodeChavo': 'a', 'Lingaro': 'a', 'Discoveries Quintessential': 'a', 'LeadSoc Technologies Pvt Ltd': 'a', 'GoodEnough Energy': 'a', 'Renjoy': 'a', 'MINDTEL': 'a', 'Jivi AI': 'a', 'MachineHack Generative AI': 'a', 'Avataar': 'a', 'TerraGiG': 'a', 'BrickRed Systems': 'a', 'Innova ESI': 'a', 'Infinit-O': 'a', 'BLJ Tech Geeks': 'a', 'Gabit': 'a', 'True Tech Professionals': 'a', 'Azmarq Technovation Private Limited': 'a', 'Raphe mPhibr': 'a', 'Varahe Analytics Private Limited': 'a', 'CleanDirty': 'a', 'Quartic.ai': 'a', 'Flam': 'a', 'Beyond&More Design': 'a', 'Sigmoid': 'a', 'Setoo': 'a', 'Yubi': 'a', 'Credgenics': 'a', 'Vensure Employer Solutions': 'a', 'Mancer Consulting Services': 'a', 'Propellence Consulting': 'a', 'Precision AQ': 'a', 'Artmac': 'a', 'Elucidata': 'a', 'Geektrust': 'a', 'Cropin': 'a', 'Teamware Solutions': 'a', 'Webologix Ltd/ INC': 'a', 'Xemplar Insights': 'a', 'Reqpedia': 'a', 'FirstHive | Customer Data Platform': 'a', 'NEXA - Digital Marketing': 'a', 'Recro': 'a', 'Animaker Inc.': 'a', 'Staqu Technologies': 'a', 'Vistec Partners': 'a', 'SNP Technologies, Inc.': 'a', 'Grizmo Labs': 'a', 'MethodHub': 'a', 'ACL Digital': 'a', 'nerdAppLabs Software Solutions Private Limited': 'a', 'EverestDX Inc': 'a', 'IndoAI Technologies': 'a', 'Thriving Springs AI': 'a', 'Where U Elevate': 'a', 'MDI NetworX': 'a', 'Agilisium Consulting': 'a', 'ZeOmega': 'a', 'Cognida.ai': 'a', 'Zzazz': 'a', 'Digile': 'a', 'RiskInsight Consulting Pvt Ltd.': 'a', 'SuperAGI': 'a', 'MSRcosmos LLC': 'a', 'Sirius Digitech': 'a', 'Stealth AI Startup': 'a', 'iAcuity Fintech': 'a', 'Atyeti Inc': 'a', 'Tezo': 'a', 'Insightzz': 'a', 'Circuitry.ai': 'a', 'Onit India': 'a', 'Dexian India': 'a', 'Upsurge Labs': 'a', 'Solytics Partners': 'a', 'Mogi I/O : OTT/Podcast/Short Video Apps for you': 'a', 'Borneo': 'a', 'Aaizel International Technologies Pvt Ltd': 'a', 'Adagrad AI': 'a', 'Space Inventive': 'a', 'SWITRUS HOLIDAYS (P) LTD': 'a', 'Fizal Outsourcing': 'a', 'Relanto': 'a', 'Blackstraw': 'a', 'ChicMic Studios': 'a', 'Parsec Solutions LLC': 'a', 'Litmus7': 'a', 'Askme Technologies': 'a', 'Ekshvaku Tech Innovations': 'a', 'STARTWITH BASICX': 'a', 'Hireginie': 'a', 'Pronix Inc': 'a', 'SalesPanda': 'a', 'IntersectIQ': 'a', 'Redian Software Global': 'a', 'SmartQ': 'a', 'TekWissen India': 'a', 'Mopid': 'a', 'Quantzig': 'a', 'ThoughtsWin Systems': 'a', 'CistekAI': 'a', 'MindInventory': 'a', 'Terawe Corporation': 'a', 'Accellor': 'a', 'Anagh Technologies Inc': 'a', 'C5i': 'a', 'Implere Technologies Pvt Ltd': 'a', 'Relyance AI': 'a', 'GKM IT': 'a', 'Wissen Technology': 'a', 'Lorven Technologies Inc.': 'a', 'Akaike Technologies': 'a', 'Webority Technologies': 'a', 'QpiAI': 'a', 'HabileLabs': 'a', 'Prudent Technologies and Consulting, Inc.': 'a', 'Talentoj': 'a', 'Runo': 'a', 'Pixelo Digital': 'a', 'DeepConverse': 'a', 'SHIELD': 'a', 'Wisemonk': 'a', 'Xceedance': 'a', 'Straive': 'a', 'Ampstek': 'a', 'Huptech HR Solutions': 'a', 'Cozzera': 'a', 'Voya India': 'a', 'Techfastic': 'a', 'Ubique Systems': 'a', 'Virtana Corp.': 'a', 'RIAmetric': 'a', 'S P A Enterprise': 'a', 'Iffort': 'a', 'BlueOptima': 'a', 'Talentgigs': 'a', 'XopunTech (India) Pvt. Ltd.': 'a', 'Rayvector Technologies': 'a', 'ICS_Jobs': 'a', 'Resolink Technologies': 'a', 'VerticalServe': 'a', 'OpenCV University': 'a', 'Niqo Robotics': 'a', 'Metropolis Technologies': 'a', 'Natoe AI': 'a', 'Fulcrum Digital Inc': 'a', 'BJS Home Delivery': 'a', 'Taggd': 'a', 'Aindra Systems': 'a', 'Academian Inc': 'a', 'WINIX Technologies Pvt Ltd': 'a', 'Pro Integrate': 'a', 'MTPL': 'a', 'Blaize': 'a', 'OTA Innovations': 'a', 'MODELIA': 'a', 'AIRA Matrix Private Limited': 'a', 'GrowthPal': 'a', 'Deccan AI': 'a', 'Altimate AI': 'a', 'ConcertAI': 'a', 'CloudZenia': 'a', 'Visual AId': 'a', 'IDfy': 'a', 'Versai': 'a', 'Datacrew.ai': 'a', 'Iris Software Inc.': 'a', 'Teleglobal International': 'a', 'iO Associates - UK/EU': 'a', 'MaxisIT Inc.': 'a', 'Canterr, Inc.': 'a', 'Ouro': 'a', 'KnowDis AI': 'a', 'The Hird': 'a', 'Darner AI Innovations': 'a', 'mokSa.ai': 'a', 'Burhani - Managed IT Services': 'a', 'ATC': 'a', 'alphastream.ai': 'a', 'Jones RecruitZo': 'a', 'thinkbridge': 'a', 'Verticurl': 'a', 'Krutrim': 'a', 'Dola AI': 'a', 'Batish Technologies Pty Ltd': 'a', 'Norstella': 'a', 'MindBrain Foundation': 'a', 'VAYUZ Technologies': 'a', 'Eternal Robotics': 'a', 'Newpage Solutions': 'a', 'Intellias': 'a', 'Novamind Tech': 'a', 'Thrillophilia.com': 'a', 'PeopleStrong': 'a', 'Macr 2': 'a', 'Moneyview': 'a', 'Jupiter AI Labs ✔': 'a', 'Resource One IT Solutions': 'a', 'MobileAppDaily': 'a', 'Gameskraft': 'a', 'Optym': 'a', 'Nisieon': 'a', 'Marketopper Securities Pvt Ltd': 'a', 'Swift Strategic Solutions Inc': 'a', 'Mitra AI': 'a', 'Vrinsoft Technology Pvt. Ltd.': 'a', 'Crescent Techservices': 'a', 'Programming.com': 'a', 'AXISCADES': 'a', 'Highbrow Technology Inc': 'a', 'Applicantz': 'a', 'Intuition IT – Intuitive Technology Recruitment': 'a', 'mthree': 'a', 'Coffeee.io': 'a', 'JK Tech': 'a', 'Aditi Consulting': 'a', 'GEDU Services': 'a', 'Baya Systems': 'a', 'Brainy Neurals - AI Company': 'a', 'Flop Hero Development Pvt Ltd': 'a', 'Timely Find': 'a', 'LawSikho': 'a', 'Walker Digital Table Systems, LLC': 'a', 'TheRecAI': 'a', 'TAC Security': 'a', 'AIGist24': 'a', 'Real Time Data Services': 'a', 'Infotree Global Solutions': 'a', 'Live D365': 'a', 'Murally Creations Pvt Ltd': 'a', 'Zupee': 'a', 'InRhythm': 'a', 'IntuCloud': 'a', 'Zyoin Group': 'a', 'Airties': 'a', 'Rosemallow Technologies Pvt Ltd': 'a', 'Anlage Infotech (India) P Ltd': 'a', 'Prodapt': 'a', 'Allinnov Research and Development Private Limited, India': 'a', 'AiSensy': 'a', 'Naatscorp Private Limited': 'a', 'Find Next Hire': 'a', 'Visit Health': 'a', 'Distributed Energy': 'a', 'Space-O Technologies': 'a', 'Veramed': 'a', 'NuMinds AI': 'a', 'WalkingTree Technologies': 'a', 'Leinex Consulting': 'a', 'qode.world': 'a', 'SUPREM.club': 'a', 'Beinex': 'a', 'Talent500': 'a', 'Digital Honchos': 'a', 'SPT Labtech': 'a', 'Primathon': 'a', 'Trigent Software - Professional Services': 'a', 't3 Strategic Partners': 'a', 'Vertisystem': 'a', 'Acorn Globus': 'a', 'ResourceTree Global Services Pvt Ltd.': 'a', 'Dautom': 'a', 'TIGI HR': 'a', 'Confidential': 'a', 'WIN Home Inspection': 'a', 'MetaModels.ai': 'a', 'Cableteque': 'a', 'Emory Technologies Inc': 'a', 'IntraEdge': 'a', 'K-RY Tech Advisory': 'a', 'White fox Designs LLP': 'a', 'Hectae Analytics and Software Solutions': 'a', 'Anubudh': 'a', 'Matillion': 'a', 'TMRW House of Brands': 'a', 'STGI': 'a', 'REA Cyber City': 'a', 'Kissht': 'a', 'Makonis': 'a', 'Turabit LLC': 'a', 'Aratt Developers': 'a', 'Bloom Consulting Services, Inc.': 'a', 'UNIQUECRYPTO GROUP': 'a', 'NeoLotex Business Solutions Private Limited': 'a', 'Sofomation': 'a', 'Systellar Technologies': 'a', 'Pantheon Digital': 'a', 'VRIZE': 'a', 'Connecting Chains': 'a', 'Cyrino': 'a', 'Glorious Insight': 'a', 'Fleet Studio': 'a', 'CYAN360': 'a', 'Quantum Integrators': 'a', 'PDI Technologies': 'a', 'Zinnia': 'a', 'Squash Apps': 'a', 'TBH': 'a', 'ANS design house': 'a', 'SDLC Corp': 'a', 'TekDoors Inc.': 'a', 'SoftClouds': 'a', 'Bonzer Business Solutions Pvt. Ltd.': 'a', 'Techtinium': 'a', 'Control Z': 'a', 'Block Trix': 'a', 'Dot & Key Skincare': 'a', 'Smart Working': 'a', 'Hack2skill': 'a', 'FLYHIGH TRAVEL LIMITED': 'a', 'Mirchi': 'a', 'NIRU Group': 'a', 'Promaynov Advisory Services Pvt. Ltd': 'a', 'TAO The Automation Office': 'a', 'QualiZeal': 'a', 'Thryve Digital Health LLP': 'a', 'BIMstream': 'a', 'Reso': 'a', 'Amity University Jharkhand': 'a', 'Sensiple': 'a', 'Convin': 'a', 'PedalStart': 'a', 'Phastar': 'a', 'Brim Labs': 'a', 'PureSoftware Ltd': 'a', 'TEKNIKOZ': 'a', 'The Family Office Company BSC (c)': 'a', 'Lo Foods': 'a', 'Qualhon Informatics Pvt. Ltd.': 'a', 'Knowbiliti': 'a', 'Adamas Tech Consulting': 'a', 'InfoGravity': 'a', 'HuntingCube Recruitment Solutions': 'a', 'NPS Prism': 'a', 'Space Matrix': 'a', 'Ambition': 'a', 'Fintech Global Center': 'a', 'Talent Sutra': 'a', 'IntegriChain': 'a', 'FPL Technologies': 'a', 'Staffing': 'a', '6thStreet.com': 'a', 'Workassist': 'a', 'ThoughtFocus': 'a', 'Wing Assistant': 'a', 'Carillon Gaming': 'a', 'StatusNeo': 'a', 'Chinar Quantum AI': 'a', 'Trellance': 'a', 'eWorkplace Apps': 'a', 'DigitalBuzz': 'a', 'BEACH RESORT IN SOUTH GOA': 'a', 'Mirafra Technologies': 'a', 'Awign Expert': 'a', 'micro1': 'a', 'HeyCoach': 'a', 'Work Store Limited': 'a', 'SoftxAI Technology Private Limited - Software & AI Solutions': 'a', 'Inxite Out': 'a', 'Mitchell Martin Inc.': 'a', 'Deltacubes': 'a', 'Amrapali Solutions': 'a', 'Tarento Group': 'a', 'Aeris IoT SaaS': 'a', 'Intelgic': 'a', 'eAspire Technolabs Pvt. Ltd.': 'a', 'Teva Pharmaceuticals': 'a', 'Celebal Technologies': 'a', 'Granicus': 'a', 'MathCo': 'a', 'Truelancer.com': 'a', 'Affle': 'a', 'LinkedIn': 'a'}
# print(co)

# %%
co={'Canopus Infosystems - A CMMI Level 3 Company': 'a', 'MobiusEngine': 'a', 'Trexquant Investment LP': 'a', 'Navi': 'a', 'Marx Enterprise Transformation Architecture': 'a', 'Quidich Innovation Labs': 'a', 'YellowSquash': 'a', 'HCLTech': 'a', 'ChainThat Limited': 'a', 'QuillBot': 'a', 'Impetus': 'a', 'Capgemini Engineering': 'a', 'BeGig': 'a', 'tsworks': 'a', 'GlobalPros': 'a', 'iMerit Technology': 'a', 'Rakuten India': 'a', 'Storable India': 'a', 'People Tech Group Inc': 'a', 'Birlasoft': 'a', 'LENS Corporation': 'a', 'TrueFan': 'a', 'Crimson Energy Experts Pvt Ltd': 'a', 'Adept Global': 'a', 'Bellurbis': 'a', 'YO IT CONSULTING': 'a', 'XpertDox': 'a', 'MindBrain': 'a', 'CodeChavo': 'a', 'HDFC Bank': 'a', 'Lingaro': 'a', 'Discoveries Quintessential': 'a', 'LeadSoc Technologies Pvt Ltd': 'a', 'GoodEnough Energy': 'a', 'Renjoy': 'a', 'MINDTEL': 'a', 'Jivi AI': 'a', 'MachineHack Generative AI': 'a', 'Avataar': 'a', 'TerraGiG': 'a', 'BrickRed Systems': 'a', 'Firstsource': 'a', 'Innova ESI': 'a', 'Infinit-O': 'a', 'BLJ Tech Geeks': 'a', 'KPIT': 'a', 'Gabit': 'a', 'Valiance Solutions': 'a', 'Netweb Technologies India Ltd.': 'a', 'True Tech Professionals': 'a', 'Azmarq Technovation Private Limited': 'a', 'Raphe mPhibr': 'a', 'Varahe Analytics Private Limited': 'a', 'CommerceIQ': 'a', 'CleanDirty': 'a', 'Quartic.ai': 'a', 'Flam': 'a', 'System Soft Technologies': 'a', 'Beyond&More Design': 'a', 'Zen Technologies Limited': 'a', 'Sigmoid': 'a', 'Setoo': 'a', 'Yubi': 'a', 'Credgenics': 'a', 'Vensure Employer Solutions': 'a', 'Mancer Consulting Services': 'a', 'Airtel International LLP-Airtel Africa': 'a', 'Propellence Consulting': 'a', 'Precision AQ': 'a', 'Artmac': 'a', 'Elucidata': 'a', 'Geektrust': 'a', 'Cropin': 'a', 'Teamware Solutions': 'a', 'Webologix Ltd/ INC': 'a', 'Xemplar Insights': 'a', 'Reqpedia': 'a', 'FirstHive | Customer Data Platform': 'a', 'NEXA - Digital Marketing': 'a', 'Recro': 'a', 'Animaker Inc.': 'a', 'Pentair': 'a', 'Staqu Technologies': 'a', 'EXL': 'a', 'Vistec Partners': 'a', 'SNP Technologies, Inc.': 'a', 'UST': 'a', 'Grizmo Labs 🌐': 'a', 'MethodHub': 'a', 'ACL Digital': 'a', 'nerdAppLabs Software Solutions Private Limited': 'a', 'EverestDX Inc': 'a', 'HDFC securities': 'a', 'IndoAI Technologies': 'a', 'TIH | IIT Bombay': 'a', 'Thriving Springs AI': 'a', 'C3IT Solutions - A Saxon Company': 'a', 'gnani.ai': 'a', 'SLK': 'a', 'Where U Elevate': 'a', 'Media.net': 'a', 'Xebia': 'a', 'MDI NetworX': 'a', 'Agilisium Consulting': 'a', 'ZeOmega': 'a', 'LTIMindtree': 'a', 'ZIGRAM': 'a', 'Cognida.ai': 'a', 'Zzazz': 'a', 'GyanSys Inc.': 'a', 'Tata Consultancy Services': 'a', 'Marlabs Software Pvt Ltd': 'a', 'Deriv': 'a', 'Digile': 'a', 'RiskInsight Consulting Pvt Ltd.': 'a', 'SuperAGI': 'a', 'MSRcosmos LLC': 'a', 'Sirius Digitech': 'a', 'Stealth AI Startup': 'a', 'iAcuity Fintech': 'a', 'Atyeti Inc': 'a', 'Tezo': 'a', 'StockX': 'a', 'Insightzz': 'a', 'Mastech Digital': 'a', 'Circuitry.ai': 'a', 'Onit India': 'a', 'AFour Technologies (An Alten Group Company)': 'a', 'Hexaware Technologies': 'a', 'Dexian India': 'a', 'Wayfair': 'a', 'Upsurge Labs': 'a', 'Birdeye': 'a', 'Coforge': 'a', 'Solytics Partners': 'a', 'Mogi I/O : OTT/Podcast/Short Video Apps for you': 'a', 'Borneo': 'a', 'Aaizel International Technologies Pvt Ltd': 'a', '': 'a'}

# %%
ques={
  "Python": "4",
  "PyTorch": "3",
  "Generative AI": "3",
  "Large Language Models": "3",
  "Machine Tools": "2",
  "Natural Language Processing": "3",
  "IT Industry Experience": "5",
  "Machine Learning": "3",
  "SQL": "3",
  "Cloud Platform": "2",
  "Artificial Intelligence": "3",
  "Current CTC (in Lakhs)": "14",
  "Expected CTC (in Lakhs)": "18",
  "Notice Period (days)": "30",
  "Node.js": "2",
  "C#": "1",
  "PHP": "1",
  "Amazon Web Services (AWS)": "2",
  "Microsoft Azure": "2",
  "Software Development": "4",
  "Data Structures and Algorithms": "4",
  "Microservices/Application Development": "3",
  "Dev-Sec-Ops": "3",
  "State-of-the-art Generative AI Models": "3",
  "ML Infrastructure": "3",
  "Technical Leadership": "3",
  "JavaScript": "3",
  "React.js": "1",
  "Large Language Model Operations (LLMOps)": "2",
  "Data Science Engineer Experience": "3",
  "MongoDB": "3",
  "DS Algorithms Experience": "5",
  "Data Engineering": "4",
  "AzureML/AzureAI or GCP Vertex AI": "3",
  "Production-ready Python Code Development": "5",
  "Azure Databricks": "3",
  "C++": "3",
  "Tableau": "3",
  "Transformer Models": "3",
  "Applied Machine Learning": "5",
  "Post-degree Work Experience": "3",
  "PySpark": "3",
  "XML": "4",
  "Django REST Framework": "3",
  "System Architecture": "3",
  "Apache Spark": "1",
  "Scala": "4",
  "MLOps": "2"
}

# %%
ques={'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with PyTorch?': '3', 'How many years of work experience do you have with Generative AI?': '3', 'How many years of work experience do you have with Large Language Models (LLM)?': '3', 'How many years of work experience do you have with Machine Tools?': '2', 'How many years of work experience do you have with Natural Language Processing (NLP)?': '3', 'Over all Experience in IT Industry?': '5', 'How many years of work experience do you have with Machine Learning?': '3', 'How many years of experience do you have in SQL': '3', 'How many years of experience you have in Cloud platform': '2', 'How many years of work experience do you have with Artificial Intelligence (AI)?': '3', 'What is your current CCTC?': '13', 
'What is your expected ECTC?': '18','Mention your notice period in number of days': '30', 'How many years of work experience do you have with Node.js?': '2', 'Total Years of Experience?': '5', 'How many years of work experience do you have with C#?': '1', 'How many years of work experience do you have with PHP?': '1'}

# %%
ques={'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Years of work experience with data structures and algorithms': '4', 'Years of experience in Microservices or Application development': '3', 'Years of experience on Dev-Sec-Ops principles and practices': '3', 'Years of work experience with state-of-the-art Generative AI models': '3', 'Years of work experience with ML infrastructure': '3', 'Years of experience in a technical leadership role': '3', 'Years of work experience with JavaScript': '3', 'Years of work experience with React.js': '1', 'Years of work experience with Large Language Model Operations (LLMOps)': '2', 'Years of experience as a Data Science Engineer': '3', 'Years of experience with Mongo DB': '3', 'Years of experience working on DS ALGORITHMS': '5', 'Years of experience in Data Engineering': '4', 'Years of experience with AzureML/AzureAI or GCP Vertex AI': '3', 'Years of experience in production ready Python code development': '5', 'Years of experience in Azure Databricks': '3', 'How soon can you join?': '30', 'Years of work experience with C++': '3', 'Years of work experience with Tableau': '3', 'Years of work experience with Transformer Models': '3', 'Years of work experience with Applied Machine Learning': '5', 'Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)': '3', 'Years of work experience with PySpark': '3', 'Years of work experience with XML': '4', 'Years of full-time experience': '5', 'Years of work experience with Django REST Framework': '3', 'Years of work experience with System Architecture': '3', 'Years of work experience with Data Structures': '4', 'Years of work experience with Apache Spark': '1', 'Years of work experience with Scala': '4', 'Relevant Experience in MLOPS': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '4', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5', 'We must fill this position urgently. Can you start immediately? Please mention your Notice Period In days': '14', 'How many years of work experience do you have with Amazon S3?': '3', 'How many years of work experience do you have with AIML?': '14', 'How many years of Consulting experience do you currently have?': '1', 'How many years of work experience do you have with DevOps?': '3', 'Years of experience in NLP and Deep Leaning?': '3', 'How many years of work experience do you have with Data Science?': '3', 'How many years of experience do you have working directly with LLMs or NLP models?': '3'}

# %%
print(len(ques))

ques={'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Years of work experience with data structures and algorithms': '4', 'Years of experience in Microservices or Application development': '3', 'Years of experience on Dev-Sec-Ops principles and practices': '3', 'Years of work experience with state-of-the-art Generative AI models': '3', 'Years of work experience with ML infrastructure': '3', 'Years of experience in a technical leadership role': '3', 'Years of work experience with JavaScript': '3', 'Years of work experience with React.js': '1', 'Years of work experience with Large Language Model Operations (LLMOps)': '2', 'Years of experience as a Data Science Engineer': '3', 'Years of experience with Mongo DB': '3', 'Years of experience working on DS ALGORITHMS': '5', 'Years of experience in Data Engineering': '4', 'Years of experience with AzureML/AzureAI or GCP Vertex AI': '3', 'Years of experience in production ready Python code development': '5', 'Years of experience in Azure Databricks': '3', 'How soon can you join?': '30', 'Years of work experience with C++': '3', 'Years of work experience with Tableau': '3', 'Years of work experience with Transformer Models': '3', 'Years of work experience with Applied Machine Learning': '5', 'Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)': '3', 'Years of work experience with PySpark': '3', 'Years of work experience with XML': '4', 'Years of full-time experience': '5', 'Years of work experience with Django REST Framework': '3', 'Years of work experience with System Architecture': '3', 'Years of work experience with Data Structures': '4', 'Years of work experience with Apache Spark': '1', 'Years of work experience with Scala': '4', 'Relevant Experience in MLOPS': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '"', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5'}
# Out:
# 73

# %%
app={'': 'a', 'job_id': 'a', 'Cozzera': 'a', 'Voya India': 'a', 'Ubique Systems': 'a', 'Virtana Corp.': 'a', 'RIAmetric': 'a', 'EdgeVerve': 'a', 'Glance': 'a', 'Chingari®': 'a', 'S P A Enterprise': 'a', 'Iffort': 'a', 'BlueOptima': 'a', 'ICS_Jobs': 'a', 'Resolink Technologies': 'a', 'Roku': 'a', 'VerticalServe': 'a', 'Magicbricks': 'a', 'Metropolis Technologies': 'a', 'Natoe AI': 'a', 'Fulcrum Digital Inc': 'a', 'Tredence Inc.': 'a', 'Algonomy': 'a', 'Aindra Systems': 'a', 'Academian Inc': 'a', 'Wipro': 'a', 'Blaize': 'a', 'Razorpay': 'a', 'Medtronic': 'a', 'Synechron': 'a', 'HERE Technologies': 'a', 'Deccan AI': 'a', 'Altimate AI': 'a', 'Ecolab': 'a', 'ConcertAI': 'a', 'AtkinsRéalis': 'a', 'IDfy': 'a', 'Datacrew.ai': 'a', 'Deutsche Telekom Digital Labs': 'a', 'KLA': 'a', 'L&T Semiconductor Technologies': 'a'}
# # print((app))

# %%
print(len(app))
# Out:
# 41

# %%
co={'Canopus Infosystems - A CMMI Level 3 Company': 'a', 'MobiusEngine': 'a', 'Trexquant Investment LP': 'a', 'Navi': 'a', 'Marx Enterprise Transformation Architecture': 'a', 'Quidich Innovation Labs': 'a', 'YellowSquash': 'a', 'HCLTech': 'a', 'ChainThat Limited': 'a', 'QuillBot': 'a', 'Impetus': 'a', 'Capgemini Engineering': 'a', 'BeGig': 'a', 'tsworks': 'a', 'GlobalPros': 'a', 'iMerit Technology': 'a', 'Rakuten India': 'a', 'Storable India': 'a', 'People Tech Group Inc': 'a', 'Birlasoft': 'a', 'LENS Corporation': 'a', 'TrueFan': 'a', 'Crimson Energy Experts Pvt Ltd': 'a', 'Adept Global': 'a', 'Bellurbis': 'a', 'YO IT CONSULTING': 'a', 'XpertDox': 'a', 'MindBrain': 'a', 'CodeChavo': 'a', 'HDFC Bank': 'a', 'Lingaro': 'a', 'Discoveries Quintessential': 'a', 'LeadSoc Technologies Pvt Ltd': 'a', 'GoodEnough Energy': 'a', 'Renjoy': 'a', 'MINDTEL': 'a', 'Jivi AI': 'a', 'MachineHack Generative AI': 'a', 'Avataar': 'a', 'TerraGiG': 'a', 'BrickRed Systems': 'a', 'Firstsource': 'a', 'Innova ESI': 'a', 'Infinit-O': 'a', 'BLJ Tech Geeks': 'a', 'KPIT': 'a', 'Gabit': 'a', 'Valiance Solutions': 'a', 'Netweb Technologies India Ltd.': 'a', 'True Tech Professionals': 'a', 'Azmarq Technovation Private Limited': 'a', 'Raphe mPhibr': 'a', 'Varahe Analytics Private Limited': 'a', 'CommerceIQ': 'a', 'CleanDirty': 'a', 'Quartic.ai': 'a', 'Flam': 'a', 'System Soft Technologies': 'a', 'Beyond&More Design': 'a', 'Zen Technologies Limited': 'a', 'Sigmoid': 'a', 'Setoo': 'a', 'Yubi': 'a', 'Credgenics': 'a', 'Vensure Employer Solutions': 'a', 'Mancer Consulting Services': 'a', 'Airtel International LLP-Airtel Africa': 'a', 'Propellence Consulting': 'a', 'Precision AQ': 'a', 'Artmac': 'a', 'Elucidata': 'a', 'Geektrust': 'a', 'Cropin': 'a', 'Teamware Solutions': 'a', 'Webologix Ltd/ INC': 'a', 'Xemplar Insights': 'a', 'Reqpedia': 'a', 'FirstHive | Customer Data Platform': 'a', 'NEXA - Digital Marketing': 'a', 'Recro': 'a', 'Animaker Inc.': 'a', 'Pentair': 'a', 'Staqu Technologies': 'a', 'EXL': 'a', 'Vistec Partners': 'a', 'SNP Technologies, Inc.': 'a', 'UST': 'a', 'Grizmo Labs 🌐': 'a', 'MethodHub': 'a', 'ACL Digital': 'a', 'nerdAppLabs Software Solutions Private Limited': 'a', 'EverestDX Inc': 'a', 'HDFC securities': 'a', 'IndoAI Technologies': 'a', 'TIH | IIT Bombay': 'a', 'Thriving Springs AI': 'a', 'C3IT Solutions - A Saxon Company': 'a', 'gnani.ai': 'a', 'SLK': 'a', 'Where U Elevate': 'a', 'Media.net': 'a', 'Xebia': 'a', 'MDI NetworX': 'a', 'Agilisium Consulting': 'a', 'ZeOmega': 'a', 'LTIMindtree': 'a', 'ZIGRAM': 'a', 'Cognida.ai': 'a', 'Zzazz': 'a', 'GyanSys Inc.': 'a', 'Tata Consultancy Services': 'a', 'Marlabs Software Pvt Ltd': 'a', 'Deriv': 'a', 'Digile': 'a', 'RiskInsight Consulting Pvt Ltd.': 'a', 'SuperAGI': 'a', 'MSRcosmos LLC': 'a', 'Sirius Digitech': 'a', 'Stealth AI Startup': 'a', 'iAcuity Fintech': 'a', 'Atyeti Inc': 'a', 'Tezo': 'a', 'StockX': 'a', 'Insightzz': 'a', 'Mastech Digital': 'a', 'Circuitry.ai': 'a', 'Onit India': 'a', 'AFour Technologies (An Alten Group Company)': 'a', 'Hexaware Technologies': 'a', 'Dexian India': 'a', 'Wayfair': 'a', 'Upsurge Labs': 'a', 'Birdeye': 'a', 'Coforge': 'a', 'Solytics Partners': 'a', 'Mogi I/O : OTT/Podcast/Short Video Apps for you': 'a', 'Borneo': 'a', 'Aaizel International Technologies Pvt Ltd': 'a', '': 'a', 'Adagrad AI': 'a', 'Space Inventive': 'a', 'SWITRUS HOLIDAYS (P) LTD': 'a', 'Fizal Outsourcing': 'a', 'Relanto': 'a', 'Blackstraw': 'a', 'ChicMic Studios': 'a', 'Mechsoft Digital Technologies Pvt. Ltd.': 'a', 'Sulekha': 'a', 'Parsec Solutions LLC': 'a', 'Litmus7': 'a', 'Askme Technologies': 'a', 'Ekshvaku Tech Innovations': 'a', 'STARTWITH BASICX': 'a', 'Hireginie': 'a', 'Pronix Inc': 'a', 'SalesPanda': 'a', 'IntersectIQ': 'a', 'Redian Software Global': 'a', 'SmartQ': 'a', 'TekWissen India': 'a', 'Mopid': 'a', 'MakeMyTrip': 'a', 'Synechron Technologies Pvt. Ltd.': 'a', 'Outsourced': 'a', 'Quantzig': 'a', 'ThoughtsWin Systems': 'a', 'CistekAI': 'a', 'CARS24': 'a', 'ESDS Software Solution Limited': 'a', 'MindInventory': 'a', 'Terawe Corporation': 'a', 'Delhivery Limited': 'a', 'Accellor': 'a', 'JioSaavn': 'a', 'Anagh Technologies Inc': 'a', 'C5i': 'a', 'Implere Technologies Pvt Ltd': 'a', 'Relyance AI': 'a', 'GKM IT': 'a', 'YASH Technologies': 'a', 'HTC Global Services': 'a', 'Wissen Technology': 'a', 'Lorven Technologies Inc.': 'a', 'Akaike Technologies': 'a', 'Webority Technologies': 'a', 'QpiAI': 'a', 'HabileLabs': 'a', 'Prudent Technologies and Consulting, Inc.': 'a', 'Sun Life': 'a', 'Talentoj': 'a', 'Runo': 'a', 'Optum': 'a', 'Pixelo Digital': 'a', 'Nagarro': 'a', 'Spirent Communications': 'a', 'DeepConverse': 'a', 'SHIELD': 'a', 'Wisemonk': 'a', 'Xceedance': 'a', 'Straive': 'a', 'Ampstek': 'a', 'Quantiphi': 'a', 'Huptech HR Solutions': 'a', 'Rapido': 'a', 'Cozzera': 'a', 'Voya India': 'a', 'Techfastic': 'a', 'Ubique Systems': 'a', 'Virtana Corp.': 'a', 'RIAmetric': 'a', 'EdgeVerve': 'a', 'Glance': 'a', 'Chingari®': 'a', 'S P A Enterprise': 'a', 'Iffort': 'a', 'BlueOptima': 'a', 'Talentgigs': 'a', 'XopunTech (India) Pvt. Ltd.': 'a', 'Rayvector Technologies': 'a', 'ICS_Jobs': 'a', 'Resolink Technologies': 'a', 'Roku': 'a', 'VerticalServe': 'a', 'OpenCV University': 'a', 'Magicbricks': 'a', 'Niqo Robotics': 'a', 'Metropolis Technologies': 'a', 'Natoe AI': 'a', 'Fulcrum Digital Inc': 'a', 'BJS Home Delivery': 'a', 'Tredence Inc.': 'a', 'Algonomy': 'a', 'Taggd': 'a', 'Aindra Systems': 'a', 'Academian Inc': 'a', 'WINIX Technologies Pvt Ltd': 'a', 'Pro Integrate': 'a', 'MTPL': 'a', 'Wipro': 'a', 'Blaize': 'a', 'OTA Innovations': 'a', 'Razorpay': 'a', 'Medtronic': 'a', 'Ashley Global Capability Center': 'a', 'Synechron': 'a', 'MODELIA': 'a', 'AIRA Matrix Private Limited': 'a', 'GrowthPal': 'a', 'HERE Technologies': 'a', 'Deccan AI': 'a', 'Altimate AI': 'a', 'Ecolab': 'a', 'ConcertAI': 'a', 'AtkinsRéalis': 'a', 'CloudZenia': 'a', 'Visual AId': 'a', 'IDfy': 'a', 'Versai': 'a', 'Datacrew.ai': 'a', 'Iris Software Inc.': 'a', 'Deutsche Telekom Digital Labs': 'a', 'KLA': 'a', 'L&T Semiconductor Technologies': 'a', 'Instabase': 'a', 'Teleglobal International': 'a', 'Coinbase': 'a', 'Cummins Inc.': 'a', 'iO Associates - UK/EU': 'a', 'ValueLabs': 'a', 'MaxisIT Inc.': 'a', 'Canterr, Inc.': 'a', 'Ouro': 'a', 'ixigo': 'a', 'Redis': 'a', 'Aspect Software': 'a', 'KnowDis AI': 'a', 'AXA XL': 'a', 'Dozen Diamonds': 'a', 'RSD Bajaj Global Law Firm': 'a', 'VMock': 'a', 'Netradyne': 'a', 'The Hird': 'a', 'TEG Analytics': 'a', 'Darner AI Innovations': 'a', 'Soon to be named': 'a', 'mokSa.ai': 'a', 'Axis Max Life Insurance Limited': 'a', 'Burhani - Managed IT Services': 'a', 'ATC': 'a', 'IQVIA': 'a', 'alphastream.ai': 'a', 'Accenture': 'a', 'Jones RecruitZo': 'a', 'thinkbridge': 'a', 'o9 Solutions, Inc.': 'a', 'Infosys': 'a', 'Verticurl': 'a', 'Velotio Technologies': 'a', 'Krutrim': 'a', 'Dola AI': 'a', 'Batish Technologies Pty Ltd': 'a', 'Norstella': 'a', 'MindBrain Foundation': 'a', 'VAYUZ Technologies': 'a', 'Eternal Robotics': 'a', 'Newpage Solutions': 'a', 'Flipkart': 'a', 'Truelancer.com': 'a', 'Intellias': 'a', 'Tata Electronics': 'a', 'Novamind Tech': 'a', 'Grant Thornton Bharat LLP': 'a', 'Thrillophilia.com': 'a', 'PeopleStrong': 'a', 'Macr 2': 'a', 'Moneyview': 'a', 'Jupiter AI Labs ✔': 'a', 'Resource One IT Solutions': 'a', 'Insight Global': 'a', 'MobileAppDaily': 'a', 'Gameskraft': 'a', 'Optym': 'a', 'Nisieon': 'a', 'PhonePe': 'a', 'Uber': 'a', 'Marketopper Securities Pvt Ltd': 'a', 'Swift Strategic Solutions Inc': 'a', 'Mitra AI': 'a', 'Vrinsoft Technology Pvt. Ltd.': 'a', 'Crescent Techservices': 'a', '7-Eleven Global Solution Center – India': 'a', 'Programming.com': 'a', 'Licious': 'a', 'AXISCADES': 'a', 'Highbrow Technology Inc': 'a', 'Applicantz': 'a', 'Intuition IT – Intuitive Technology Recruitment': 'a', 'Turing': 'a', 'Sonata Software': 'a', 'mthree': 'a', 'TEKsystems': 'a', 'Coffeee.io': 'a', 'JK Tech': 'a', 'Expleo Group': 'a', 'Aditi Consulting': 'a', 'SoundHound AI': 'a', 'Tiger Analytics': 'a', 'GEDU Services': 'a', 'Baya Systems': 'a', 'Sinch': 'a', 'Brainy Neurals - AI Company': 'a', 'Flop Hero Development Pvt Ltd': 'a', 'L&T Technology Services': 'a', 'Antal International': 'a', 'Timely Find': 'a', 'Sony Pictures Networks India': 'a', 'LawSikho': 'a', 'upGrad': 'a', 'EVERSANA': 'a', 'Walker Digital Table Systems, LLC': 'a', 'TheRecAI': 'a', 'TAC Security': 'a', 'AIGist24': 'a', 'Real Time Data Services': 'a', 'Infotree Global Solutions': 'a', 'Live D365': 'a', 'Groww': 'a', 'Murally Creations Pvt Ltd': 'a', 'noon': 'a', 'RAAD7 INFORMATICS PVT LIMITED': 'a', 'Oracle': 'a', 'Zupee': 'a', 'Appinventiv': 'a', 'InRhythm': 'a', 'IntuCloud': 'a', 'Zyoin Group': 'a', 'Airties': 'a', 'Rosemallow Technologies Pvt Ltd': 'a', 'Anlage Infotech (India) P Ltd': 'a', 'Intelliswift - An LTTS Company': 'a', 'Prodapt': 'a', 'Allinnov Research and Development Private Limited, India': 'a', 'AiSensy': 'a', 'Naatscorp Private Limited': 'a', 'Find Next Hire': 'a', 'Visit Health': 'a', 'Distributed Energy': 'a', 'PubMatic': 'a', 'Space-O Technologies': 'a', 'Veramed': 'a', 'NuMinds AI': 'a', 'WalkingTree Technologies': 'a', 'Tesco Bengaluru': 'a', 'Leinex Consulting': 'a', 'qode.world': 'a', 'redBus': 'a', 'SUPREM.club': 'a', 'Beinex': 'a', 'Talent500': 'a', 'Digital Honchos': 'a', 'SPT Labtech': 'a', 'Primathon': 'a', 'Trigent Software - Professional Services': 'a', 't3 Strategic Partners': 'a', 'Vertisystem': 'a', 'Acorn Globus': 'a', 'ResourceTree Global Services Pvt Ltd.': 'a', 'Dautom': 'a', 'TIGI HR': 'a', 'Confidential': 'a', 'WIN Home Inspection': 'a', 'MetaModels.ai': 'a', 'Cableteque': 'a', 'Emory Technologies Inc': 'a', 'BDO in India': 'a', 'LivePerson': 'a', 'IntraEdge': 'a', 'Circle K': 'a', 'K-RY Tech Advisory': 'a', 'Apparel Group': 'a', 'White fox Designs LLP': 'a', 'Hectae Analytics and Software Solutions': 'a', 'Anubudh': 'a', 'Matillion': 'a', 'TMRW House of Brands': 'a', 'STGI': 'a', 'REA Cyber City': 'a', 'Evalueserve India': 'a', 'Equiniti': 'a', 'Kissht': 'a', 'Makonis': 'a', 'Turabit LLC': 'a', 'Aratt Developers': 'a', 'Bloom Consulting Services, Inc.': 'a', 'PCS InfoTech': 'a', 'UNIQUECRYPTO GROUP': 'a', 'NeoLotex Business Solutions Private Limited': 'a', 'PW (PhysicsWallah)': 'a', 'Branch International': 'a', 'Sofomation': 'a', 'GEMRAJ TECHNOLOGIES LIMITED': 'a', 'Systellar Technologies': 'a', 'Pantheon Digital': 'a', 'VRIZE': 'a', 'Connecting Chains': 'a', 'Cyrino': 'a', 'Apollo Hospitals': 'a', 'Glorious Insight': 'a', 'Fleet Studio': 'a', 'CYAN360': 'a', 'PTC': 'a', 'Quantum Integrators': 'a', 'PDI Technologies': 'a', 'Zinnia': 'a', 'Squash Apps': 'a', 'TBH': 'a', 'ANS design house': 'a', 'SDLC Corp': 'a', 'TekDoors Inc.': 'a', 'SoftClouds': 'a', 'Bonzer Business Solutions Pvt. Ltd.': 'a', 'Techtinium': 'a', 'Control Z': 'a', 'Block Trix': 'a', 'Evernorth Health Services': 'a', 'Dot & Key Skincare': 'a', 'Freshworks': 'a', 'Smart Working': 'a', 'Hack2skill': 'a', 'FLYHIGH TRAVEL LIMITED': 'a', 'Mirchi': 'a', 'Fortune 500 Companies': 'a', 'Preqin': 'a', 'IndusInd Bank Limited': 'a', 'Javin': 'a', 'QAD': 'a', 'Chargebee': 'a', 'NIRU Group': 'a', 'Promaynov Advisory Services Pvt. Ltd': 'a', 'TAO The Automation Office': 'a', 'PwC Acceleration Centers in India': 'a', 'QualiZeal': 'a', 'Thryve Digital Health LLP': 'a', 'Everest Group': 'a', 'BIMstream': 'a', 'Reso': 'a', 'Amity University Jharkhand': 'a', 'Sensiple': 'a', 'Skuad: a Payoneer company': 'a', 'Precision For Medicine': 'a', 'Western Digital': 'a', 'Convin': 'a', 'NielsenIQ': 'a', 'lululemon': 'a', 'Volkswagen Group Technology Solutions India': 'a', 'Brillio': 'a', 'Servion Global Solutions': 'a', 'MediaTek': 'a', 'INDO GROUP': 'a', 'PedalStart': 'a', 'Phastar': 'a', 'Brim Labs': 'a', 'PureSoftware Ltd': 'a'}

# %%
# print(len(ques))
"""ques={
  "Years of work experience with Python": "4",
  "Years of work experience with PyTorch": "3",
  "Years of work experience with Generative AI": "3",
  "Years of work experience with Large Language Models (LLM)": "3",
  "Years of work experience with Machine Tools": "2",
  "Years of work experience with Natural Language Processing (NLP)": "3",
  "Years of work experience with Machine Learning": "3",
  "Years of experience in SQL": "3",
  "Years of experience in Cloud platform": "2",
  "Years of work experience with Artificial Intelligence (AI)": "3",
  "Current CTC (LPA)": "14",
  "Expected CTC (LPA)": "18",
  "Notice Period (days)": "30",
  "Years of work experience with Node.js": "2",
  "Total Years of Experience": "5",
  "Years of work experience with C#": "1",
  "Years of work experience with PHP": "1",
  "Years of work experience with Amazon Web Services (AWS)": "2",
  "Years of work experience with Microsoft Azure": "2",
  "Years of experience in software development": "4",
  "Years of work experience with data structures and algorithms": "4",
  "Years of experience in Microservices or Application development": "3",
  "Years of experience on Dev-Sec-Ops principles and practices": "3",
  "Years of work experience with ML infrastructure": "3",
  "Years of experience in a technical leadership role": "3",
  "Years of work experience with JavaScript": "3",
  "Years of work experience with React.js": "1",
  "Years of work experience with Large Language Model Operations (LLMOps)": "2",
  "Years of experience as a Data Science Engineer": "3",
  "Years of experience with Mongo DB": "3",
  "Years of experience working on DS ALGORITHMS": "5",
  "Years of experience in Data Engineering": "4",
  "Years of experience with AzureML/AzureAI or GCP Vertex AI": "3",
  "Years of experience in production ready Python code development": "5",
  "Years of experience in Azure Databricks": "3",
  "Years of work experience with C++": "3",
  "Years of work experience with Tableau": "3",
  "Years of work experience with Transformer Models": "3",
  "Years of work experience with Applied Machine Learning": "5",
  "Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)": "3",
  "Years of work experience with PySpark": "3",
  "Years of work experience with XML": "4",
  "Years of work experience with Django REST Framework": "3",
  "Years of work experience with System Architecture": "3",
  "Years of work experience with Apache Spark": "1",
  "Years of work experience with Scala": "4",
  "Relevant Experience in MLOPS": "2",
  "How many years of work experience do you have with ClickHouse?": "1",
  "How many years of work experience do you have with Extract, Transform, Load (ETL)?": "14",
  "How many years of work experience do you have in AWS/GCP/Azure?": "3",
  "How many years of work experience do you have in relational database (RDBMS)?": "3",
  "How many years of work experience do you have in web technologies?": "3",
  "How many years of work experience do you have with AWS Lambda?": "3",
  "Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?": "good",
  "How many years of work experience do you have with Troubleshooting and debugging of code?": "3",
  "How many years of work experience do you have with Software as a Service (SaaS)?": "5",
  "How many years of work experience do you have with TensorFlow?": "4",
  "How many years of work experience do you have with Image Processing?": "3",
  "How many years of work experience do you have with Computer Vision?": "3",
  "How many years of work experience do you have in Networking concepts and protocols ?": "5",
  "Years of work experience in a product based company": "4",
  "How many years of work experience do you have with Snowflake?": "4",
  "How many years of work experience do you have with Neural Networks?": "5",
  "How many years of work experience do you have with Amazon S3?": "3",
  "How many years of work experience do you have with AIML?": "14",
  "How many years of Consulting experience do you currently have?": "1",
  "How many years of work experience do you have with DevOps?": "3",
  "How many years of work experience do you have with Data Science?": "3",
  "How many years of experience do you have with Python for Computer Vision tasks?": "14",
  "How many years of work experience do you have with Chatbot Development?": "2",
  "How many years of work experience do you have with Databases?": "4",
  "How many years of work experience do you have with Deep Learning?": "3",
  "What is your Whatsapp number?": "8077975459",
  "How many years of work experience do you have with UiPath?": "3",
  "How many years of work experience do you have with Django?": "3",
  "How many years of work experience do you have with Java?": "2",
  "How many years of work experience do you have with Design Patterns?": "3",
  "How many years of experience do you have in Azure Data Factory": "2",
  "How many years of experience do you have in Azure Kubernetes Service": "2",
  "How many years of experience do you have in Python, R, or C#?": "4",
  "How many years of work experience do you have with Azure Synapse Analytics": "2",
  "How many years of work experience do you have with AWS SageMaker?": "3",
  "Do you have any offers in Hand? If yes mention the number": "1",
  "How many years of work experience do you have with Data Analytics?": "3",
  "How many years of work experience do you have with Database Management System (DBMS)?": "4",
  "How many engineers or team members have you directly managed in your previous roles?": "10",
  "How many years of work experience do you have with springboot?": "2",
  "How many years of experience you have as an Engineering Maanger?": "4",
  "How many years of work experience do you have with Test Automation Tools?": "14",
  "How many years of work experience do you have with Machine Learning Algorithms?": "3",
  "How many years of experience you have as a Data Scientist in CPG domain?": "1",
  "How many years of experience you have for Market mix modelling?": "1",
  "How many years of work experience do you have with Technical Architecture?": "2",
  "How many years of experience do you have in information retrieval?": "3",
  "How many years of experience do you have with Heuristics/Meta-Heuristics?": "1",
  "How many years of experience as an ETL Developer?": "3",
  "How many years of work experience do you have with Azure's durable function?": "2",
  "How many years of work experience do you have with Fivetran?": "1",
  "How many years of work experience do you have with Software Architecture?": "3",
  "How many years of work experience do you have with FastAPI?": "2",
  "How many years of work experience do you have with Twilio?": "1",
  "How many years of work experience do you have with TTS?": "3",
  "What’s your experience with agent-based LLM chains?": "3",
  "Expected in hand salary?": "5",
  "How many years of work experience do you have with Flask?": "3",
  "How many years of work experience do you have with Jenkins?": "2",
  "How many years of work experience do you have with Microsoft Excel?": "3",
  "How many years of work experience do you have with Spring Framework?": "2",
  "How many years of work experience do you have with Apache?": "2",
  "Proficiency in Python and the ability to write a small piece of code.": "4",
  "How many years of work experience do you have with Client Communication?": "3",
  "How many years of work experience do you have with pytest?": "3",
  "How many years of work experience do you have with Data Validation?": "3",
  "How many years of work experience do you have with API Testing?": "2",
  "How many years of work experience do you have with Python Automation?": "4",
  "How many years of work experience do you have with TypeScript?": "2",
  "LinkedIn Profile": "vashisth malik",
  "Website": "",
  "How many years of experience do you have working on server side software (backend)?": "4",
  "How many years of experience you have in developing on Linux? Additionally, are you proficient in Linux and its command-line tools? If you have utilized Linux command-line tools in your projects, could you elaborate on the tasks you performed using them?": "2",
  "Which scripting languages are you proficient in? (Python is preferred, but Bash is also acceptable.)": "3",
  "If a SoundHound employee referred you to this job, please provide their name and the context in which you know each other.": "na",
  "How many years of work experience do you have with Selenium?": "4",
  "What is your current monthly salary?": "14",
  "How many years of experience do you have in training/teaching data science?": "4",
  "How many years of work experience do you have with CDISC Standards?": "1",
  "If Yes to above, please provide details - Name of Tesco Entity you worked for, Employee Serial Number, Tenure ( From To), Location of employment": "na",
  "If you select Other in the above question, please state what eligibility you have to work in India": "na",
  "Your message to the hiring manager": "na",
  "What is your current location?": "meerut",
  "Reason for change?": "na",
  "What primary technologies have you used or experienced in?": "4",
  "How many years of work experience do you have with Atlas?": "0",
  "How many years of work experience do you have with MySQL?": "1",
  "How many experience do you have in Golang": "14",
  "How many years of experience you have into software design and programming?": "5",
  "How many years of experience do you have in model development?": "3",
  "Name as per Pan Card": "vashisht malik",
  "What are your main technical skills?": "python",
  "How many years of work experience do you have with ASP.NET Core?": "3",
  "Relevant experience as a Technical Architect": "2"
}
"""
ques={'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Years of work experience with data structures and algorithms': '4', 'Years of experience in Microservices or Application development': '3', 'Years of experience on Dev-Sec-Ops principles and practices': '3', 'Years of work experience with state-of-the-art Generative AI models': '3', 'Years of work experience with ML infrastructure': '3', 'Years of experience in a technical leadership role': '3', 'Years of work experience with JavaScript': '3', 'Years of work experience with React.js': '1', 'Years of work experience with Large Language Model Operations (LLMOps)': '2', 'Years of experience as a Data Science Engineer': '3', 'Years of experience with Mongo DB': '3', 'Years of experience working on DS ALGORITHMS': '5', 'Years of experience in Data Engineering': '4', 'Years of experience with AzureML/AzureAI or GCP Vertex AI': '3', 'Years of experience in production ready Python code development': '5', 'Years of experience in Azure Databricks': '3', 'How soon can you join?': '30', 'Years of work experience with C++': '3', 'Years of work experience with Tableau': '3', 'Years of work experience with Transformer Models': '3', 'Years of work experience with Applied Machine Learning': '5', 'Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)': '3', 'Years of work experience with PySpark': '3', 'Years of work experience with XML': '4', 'Years of full-time experience': '5', 'Years of work experience with Django REST Framework': '3', 'Years of work experience with System Architecture': '3', 'Years of work experience with Data Structures': '4', 'Years of work experience with Apache Spark': '1', 'Years of work experience with Scala': '4', 'Relevant Experience in MLOPS': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '4', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5', 'We must fill this position urgently. Can you start immediately? Please mention your Notice Period In days': '14', 'How many years of work experience do you have with Amazon S3?': '3', 'How many years of work experience do you have with AIML?': '14', 'How many years of Consulting experience do you currently have?': '1', 'How many years of work experience do you have with DevOps?': '3', 'Years of experience in NLP and Deep Leaning?': '3', 'How many years of work experience do you have with Data Science?': '3', 'How many years of experience do you have working directly with LLMs or NLP models?': '3', 'How many years of experience do you have with Python for Computer Vision tasks?': '14', 'How many years of work experience do you have with Chatbot Development?': '2', 'How many years of work experience do you have with Databases?': '4', 'How many years of work experience do you have with AI/ML?': '3', 'How many years of work experience do you have with Deep Learning?': '3', 'What is your Whatsapp number?': '8077975459', 'How many years of work experience do you have with UiPath?': '3', 'How many years of work experience do you have with Django?': '3', 'How many years of work experience do you have with Java?': '2', 'How many years of work experience do you have with Design Patterns?': '3', 'How many years of experience do you have in Azure Data Factory': '2', 'How many years of experience do you have in Azure Kubernetes Service': '2', 'How many years of experience do you have in Python, R, or C#?': '4', 'How many years of work experience do you have with Azure Synapse Analytics': '2', 'How many years of work experience do you have with AWS SageMaker?': '3', 'Current CTC (Enter full number)': '14', 'Do you have any offers in Hand? If yes mention the number': '1', 'How many years of work experience do you have with Data Analytics?': '3', 'How many years of work experience do you have with Database Management System (DBMS)?': '4', 'How many engineers or team members have you directly managed in your previous roles?': '10', 'How many years of work experience do you have with springboot?': '2', 'How many years of experience you have as an Engineering Maanger?': '4', 'How many years of work experience do you have with Test Automation Tools?': '14', 'How many years of work experience do you have with Machine Learning Algorithms?': '3', 'How many years of experience you have as a Data Scientist in CPG domain?': '1', 'How many years of experience you have for Market mix modelling?': '1', 'How many years of work experience do you have with Technical Architecture?': '2', 'How many years of experience do you have in information retrieval?': '3', 'How many years of experience do you have with Heuristics/Meta-Heuristics?': '1', 'How many years of experience as an ETL Developer?': '3', "How many years of work experience do you have with Azure's durable function?": '2', 'How many years of work experience do you have with Fivetran?': '1', 'How many years of work experience do you have with Software Architecture?': '3', 'How many years of work experience do you have with FastAPI?': '2', 'How many years of work experience do you have with Twilio?': '1', 'How many years of work experience do you have with TTS?': '3', 'What’s your experience with agent-based LLM chains?': '3', 'Expected in hand salary?': '5', 'How many years of work experience do you have with Flask?': '3', 'How many years of work experience do you have with Jenkins?': '2', 'How many years of work experience do you have with Microsoft Excel?': '3', 'How many years of work experience do you have with Spring Framework?': '2', 'How many years of work experience do you have with Apache?': '2', 'Proficiency in Python and the ability to write a small piece of code.': '4', 'How many years of work experience do you have with Client Communication?': '3', 'How many years of work experience do you have with pytest?': '3', 'How many years of work experience do you have with Data Validation?': '3', 'How many years of work experience do you have with API Testing?': '2', 'How many years of work experience do you have with Python Automation?': '4', 'Expected CTC? Apply only if its below 9lpa': '18', 'How many years of work experience do you have with TypeScript?': '2', 'LinkedIn Profile': 'vashisth malik', 'Website': '""', 'How many years of experience do you have working on server side software (backend)?': '4', 'How many years of experience you have in developing on Linux? Additionally, are you proficient in Linux and its command-line tools? If you have utilized Linux command-line tools in your projects, could you elaborate on the tasks you performed using them?': '2', 'Which scripting languages are you proficient in? (Python is preferred, but Bash is also acceptable.)': '3', 'If a SoundHound employee referred you to this job, please provide their name and the context in which you know each other.': 'na', 'How many years of work experience do you have with Selenium?': '4', 'What is your current monthly salary?': '14', 'How many years of experience do you have in training/teaching data science?': '4', 'What is your expectation in terms of (Gross) Per Month Salary': '18', 'How many years of work experience do you have as a Javascript Fullstack Developer?': '14', 'How many years of work experience do you have with Unix?': 'q', 'How many years of work experience do you have with Linux?': '3', 'How many years of work experience do you have with CDISC Standards?': '1', 'If Yes to above, please provide details - Name of Tesco Entity you worked for, Employee Serial Number, Tenure ( From To), Location of employment': 'na', 'If you select Other in the above question, please state what eligibility you have to work in India': 'na', 'Your message to the hiring manager': 'na', 'What is your current location?': 'meerut', 'Reason for change?': 'na', 'What primary technologies have you used or experienced in?': '4', 'What is your minimum annual Salary expectation (Base/Fixed) ?': '14', 'How many years of work experience do you have with Atlas?': '0', 'What are your salary expectations?': '18', 'How many years of work experience do you have with MySQL?': '1', 'How many experience do you have in Golang': '14', 'What is your Expected Annual Salary ?': '18', 'How many years of experience you have into software design and programming?': '5', 'How many years of experience do you have in model development?': '3', 'Name as per Pan Card': 'vashisht malik', 'What are your main technical skills?': 'python', 'How many years of work experience do you have with ASP.NET Core?': '3', 'Relevant experience as a Technical Architect': '2'}

# %%
print(co)
# Out:
# {'Canopus Infosystems - A CMMI Level 3 Company': 'a', 'MobiusEngine': 'a', 'Trexquant Investment LP': 'a', 'Navi': 'a', 'Marx Enterprise Transformation Architecture': 'a', 'Quidich Innovation Labs': 'a', 'YellowSquash': 'a', 'HCLTech': 'a', 'ChainThat Limited': 'a', 'QuillBot': 'a', 'Impetus': 'a', 'Capgemini Engineering': 'a', 'BeGig': 'a', 'tsworks': 'a', 'GlobalPros': 'a', 'iMerit Technology': 'a', 'Rakuten India': 'a', 'Storable India': 'a', 'People Tech Group Inc': 'a', 'Birlasoft': 'a', 'LENS Corporation': 'a', 'TrueFan': 'a', 'Crimson Energy Experts Pvt Ltd': 'a', 'Adept Global': 'a', 'Bellurbis': 'a', 'YO IT CONSULTING': 'a', 'XpertDox': 'a', 'MindBrain': 'a', 'CodeChavo': 'a', 'HDFC Bank': 'a', 'Lingaro': 'a', 'Discoveries Quintessential': 'a', 'LeadSoc Technologies Pvt Ltd': 'a', 'GoodEnough Energy': 'a', 'Renjoy': 'a', 'MINDTEL': 'a', 'Jivi AI': 'a', 'MachineHack Generative AI': 'a', 'Avataar': 'a', 'TerraGiG': 'a', 'BrickRed Systems': 'a', 'Firstsource': 'a', 'Innova ESI'
# ...

# %%
co={'MobiusEngine': 'a', 'Quidich Innovation Labs': 'a', 'YellowSquash': 'a', 'ChainThat Limited': 'a', 'QuillBot': 'a', 'Impetus': 'a', 'BeGig': 'a', 'tsworks': 'a', 'GlobalPros': 'a', 'iMerit Technology': 'a', 'Storable India': 'a', 'People Tech Group Inc': 'a', 'LENS Corporation': 'a', 'TrueFan': 'a', 'Crimson Energy Experts Pvt Ltd': 'a', 'Adept Global': 'a', 'Bellurbis': 'a', 'YO IT CONSULTING': 'a', 'XpertDox': 'a', 'MindBrain': 'a', 'CodeChavo': 'a', 'Lingaro': 'a', 'Discoveries Quintessential': 'a', 'LeadSoc Technologies Pvt Ltd': 'a', 'GoodEnough Energy': 'a', 'Renjoy': 'a', 'MINDTEL': 'a', 'Jivi AI': 'a', 'MachineHack Generative AI': 'a', 'Avataar': 'a', 'TerraGiG': 'a', 'BrickRed Systems': 'a', 'Innova ESI': 'a', 'Infinit-O': 'a', 'BLJ Tech Geeks': 'a', 'Gabit': 'a', 'True Tech Professionals': 'a', 'Azmarq Technovation Private Limited': 'a', 'Raphe mPhibr': 'a', 'Varahe Analytics Private Limited': 'a', 'CommerceIQ': 'a', 'CleanDirty': 'a', 'Quartic.ai': 'a', 'Flam': 'a', 'System Soft Technologies': 'a', 'Beyond&More Design': 'a', 'Sigmoid': 'a', 'Setoo': 'a', 'Yubi': 'a', 'Credgenics': 'a', 'Vensure Employer Solutions': 'a', 'Mancer Consulting Services': 'a', 'Propellence Consulting': 'a', 'Precision AQ': 'a', 'Artmac': 'a', 'Elucidata': 'a', 'Geektrust': 'a', 'Cropin': 'a', 'Teamware Solutions': 'a', 'Webologix Ltd/ INC': 'a', 'Xemplar Insights': 'a', 'Reqpedia': 'a', 'FirstHive | Customer Data Platform': 'a', 'NEXA - Digital Marketing': 'a', 'Recro': 'a', 'Animaker Inc.': 'a', 'Staqu Technologies': 'a', 'Vistec Partners': 'a', 'SNP Technologies, Inc.': 'a', 'Grizmo Labs ': 'a', 'MethodHub': 'a', 'ACL Digital': 'a', 'nerdAppLabs Software Solutions Private Limited': 'a', 'EverestDX Inc': 'a', 'IndoAI Technologies': 'a', 'Thriving Springs AI': 'a',  'SLK': 'a', 'Where U Elevate': 'a', 'Media.net': 'a', 'MDI NetworX': 'a', 'Agilisium Consulting': 'a', 'ZeOmega': 'a', 'Cognida.ai': 'a', 'Zzazz': 'a', 'GyanSys Inc.': 'a', 'Marlabs Software Pvt Ltd': 'a', 'Deriv': 'a', 'Digile': 'a', 'RiskInsight Consulting Pvt Ltd.': 'a', 'SuperAGI': 'a', 'MSRcosmos LLC': 'a', 'Sirius Digitech': 'a', 'Stealth AI Startup': 'a', 'iAcuity Fintech': 'a', 'Atyeti Inc': 'a', 'Tezo': 'a', 'Insightzz': 'a', 'Mastech Digital': 'a', 'Circuitry.ai': 'a', 'Onit India': 'a', 'AFour Technologies (An Alten Group Company)': 'a', 'Dexian India': 'a', 'Upsurge Labs': 'a', 'Birdeye': 'a', 'Solytics Partners': 'a', 'Mogi I/O : OTT/Podcast/Short Video Apps for you': 'a', 'Borneo': 'a', 'Aaizel International Technologies Pvt Ltd': 'a', 'Adagrad AI': 'a', 'Space Inventive': 'a', 'SWITRUS HOLIDAYS (P) LTD': 'a', 'Fizal Outsourcing': 'a', 'Relanto': 'a', 'Blackstraw': 'a', 'ChicMic Studios': 'a', 'Mechsoft Digital Technologies Pvt. Ltd.': 'a', 'Sulekha': 'a', 'Parsec Solutions LLC': 'a', 'Litmus7': 'a', 'Askme Technologies': 'a', 'Ekshvaku Tech Innovations': 'a', 'STARTWITH BASICX': 'a', 'Hireginie': 'a', 'Pronix Inc': 'a', 'SalesPanda': 'a', 'IntersectIQ': 'a', 'Redian Software Global': 'a', 'SmartQ': 'a', 'TekWissen India': 'a', 'Mopid': 'a', 'Outsourced': 'a', 'Quantzig': 'a', 'ThoughtsWin Systems': 'a', 'CistekAI': 'a', 'ESDS Software Solution Limited': 'a', 'MindInventory': 'a', 'Terawe Corporation': 'a', 'Accellor': 'a', 'Anagh Technologies Inc': 'a', 'C5i': 'a', 'Implere Technologies Pvt Ltd': 'a', 'Relyance AI': 'a', 'GKM IT': 'a', 'Wissen Technology': 'a', 'Lorven Technologies Inc.': 'a', 'Akaike Technologies': 'a', 'Webority Technologies': 'a', 'QpiAI': 'a', 'HabileLabs': 'a', 'Prudent Technologies and Consulting, Inc.': 'a', 'Talentoj': 'a', 'Runo': 'a', 'Pixelo Digital': 'a', 'Nagarro': 'a', 'Spirent Communications': 'a', 'DeepConverse': 'a', 'SHIELD': 'a', 'Wisemonk': 'a', 'Xceedance': 'a', 'Straive': 'a', 'Ampstek': 'a', 'Huptech HR Solutions': 'a', 'Rapido': 'a', 'Cozzera': 'a', 'Voya India': 'a', 'Techfastic': 'a', 'Ubique Systems': 'a', 'Virtana Corp.': 'a', 'RIAmetric': 'a', 'EdgeVerve': 'a', 'Glance': 'a', 'Chingari': 'a', 'S P A Enterprise': 'a', 'Iffort': 'a', 'BlueOptima': 'a', 'Talentgigs': 'a', 'XopunTech (India) Pvt. Ltd.': 'a', 'Rayvector Technologies': 'a', 'ICS_Jobs': 'a', 'Resolink Technologies': 'a', 'VerticalServe': 'a', 'OpenCV University': 'a', 'Magicbricks': 'a', 'Niqo Robotics': 'a', 'Metropolis Technologies': 'a', 'Natoe AI': 'a', 'Fulcrum Digital Inc': 'a', 'BJS Home Delivery': 'a', 'Tredence Inc.': 'a', 'Algonomy': 'a', 'Taggd': 'a', 'Aindra Systems': 'a', 'Academian Inc': 'a', 'WINIX Technologies Pvt Ltd': 'a', 'Pro Integrate': 'a', 'MTPL': 'a', 'Blaize': 'a', 'OTA Innovations': 'a', 'Razorpay': 'a', 'Ashley Global Capability Center': 'a', 'MODELIA': 'a', 'AIRA Matrix Private Limited': 'a', 'GrowthPal': 'a', 'HERE Technologies': 'a', 'Deccan AI': 'a', 'Altimate AI': 'a', 'ConcertAI': 'a', 'AtkinsRéalis': 'a', 'CloudZenia': 'a', 'Visual AId': 'a', 'IDfy': 'a', 'Versai': 'a', 'Datacrew.ai': 'a', 'Iris Software Inc.': 'a', 'Deutsche Telekom Digital Labs': 'a', 'KLA': 'a', 'L&T Semiconductor Technologies': 'a', 'Instabase': 'a', 'Teleglobal International': 'a', 'Cummins Inc.': 'a', 'iO Associates - UK/EU': 'a', 'ValueLabs': 'a', 'MaxisIT Inc.': 'a', 'Canterr, Inc.': 'a', 'Ouro': 'a', 'ixigo': 'a', 'Redis': 'a', 'Aspect Software': 'a', 'KnowDis AI': 'a', 'The Hird': 'a', 'Darner AI Innovations': 'a', 'Soon to be named': 'a', 'mokSa.ai': 'a', 'Burhani - Managed IT Services': 'a', 'ATC': 'a', 'alphastream.ai': 'a', 'Jones RecruitZo': 'a', 'thinkbridge': 'a', 'o9 Solutions, Inc.': 'a', 'Verticurl': 'a', 'Velotio Technologies': 'a', 'Krutrim': 'a', 'Dola AI': 'a', 'Batish Technologies Pty Ltd': 'a', 'Norstella': 'a', 'MindBrain Foundation': 'a', 'VAYUZ Technologies': 'a', 'Eternal Robotics': 'a', 'Newpage Solutions': 'a', 'Truelancer.com': 'a', 'Intellias': 'a', 'Novamind Tech': 'a', 'Grant Thornton Bharat LLP': 'a', 'Thrillophilia.com': 'a', 'PeopleStrong': 'a', 'Macr 2': 'a', 'Moneyview': 'a', 'Jupiter AI Labs ✔': 'a', 'Resource One IT Solutions': 'a', 'Insight Global': 'a', 'MobileAppDaily': 'a', 'Gameskraft': 'a', 'Optym': 'a', 'Nisieon': 'a', 'Marketopper Securities Pvt Ltd': 'a', 'Swift Strategic Solutions Inc': 'a', 'Mitra AI': 'a', 'Vrinsoft Technology Pvt. Ltd.': 'a', 'Crescent Techservices': 'a', '7-Eleven Global Solution Center – India': 'a', 'Programming.com': 'a', 'Licious': 'a', 'AXISCADES': 'a', 'Highbrow Technology Inc': 'a', 'Applicantz': 'a', 'Intuition IT – Intuitive Technology Recruitment': 'a', 'Turing': 'a', 'Sonata Software': 'a', 'mthree': 'a', 'TEKsystems': 'a', 'Coffeee.io': 'a', 'JK Tech': 'a', 'Expleo Group': 'a', 'Aditi Consulting': 'a', 'SoundHound AI': 'a', 'Tiger Analytics': 'a', 'GEDU Services': 'a', 'Baya Systems': 'a', 'Sinch': 'a', 'Brainy Neurals - AI Company': 'a', 'Flop Hero Development Pvt Ltd': 'a', 'L&T Technology Services': 'a', 'Antal International': 'a', 'Timely Find': 'a', 'LawSikho': 'a', 'upGrad': 'a', 'EVERSANA': 'a', 'Walker Digital Table Systems, LLC': 'a', 'TheRecAI': 'a', 'TAC Security': 'a', 'AIGist24': 'a', 'Real Time Data Services': 'a', 'Infotree Global Solutions': 'a', 'Live D365': 'a', 'Groww': 'a', 'Murally Creations Pvt Ltd': 'a', 'noon': 'a', 'RAAD7 INFORMATICS PVT LIMITED': 'a', 'Zupee': 'a', 'Appinventiv': 'a', 'InRhythm': 'a', 'IntuCloud': 'a', 'Zyoin Group': 'a', 'Airties': 'a', 'Rosemallow Technologies Pvt Ltd': 'a', 'Anlage Infotech (India) P Ltd': 'a', 'Intelliswift - An LTTS Company': 'a', 'Prodapt': 'a', 'Allinnov Research and Development Private Limited, India': 'a', 'AiSensy': 'a', 'Naatscorp Private Limited': 'a', 'Find Next Hire': 'a', 'Visit Health': 'a', 'Distributed Energy': 'a', 'PubMatic': 'a', 'Space-O Technologies': 'a', 'Veramed': 'a', 'NuMinds AI': 'a', 'WalkingTree Technologies': 'a', 'Leinex Consulting': 'a', 'qode.world': 'a', 'SUPREM.club': 'a', 'Beinex': 'a', 'Talent500': 'a', 'Digital Honchos': 'a', 'SPT Labtech': 'a', 'Primathon': 'a', 'Trigent Software - Professional Services': 'a', 't3 Strategic Partners': 'a', 'Vertisystem': 'a', 'Acorn Globus': 'a', 'ResourceTree Global Services Pvt Ltd.': 'a', 'Dautom': 'a', 'TIGI HR': 'a', 'Confidential': 'a', 'WIN Home Inspection': 'a', 'MetaModels.ai': 'a', 'Cableteque': 'a', 'Emory Technologies Inc': 'a', 'LivePerson': 'a', 'IntraEdge': 'a', 'K-RY Tech Advisory': 'a', 'Apparel Group': 'a', 'White fox Designs LLP': 'a', 'Hectae Analytics and Software Solutions': 'a', 'Anubudh': 'a', 'Matillion': 'a', 'TMRW House of Brands': 'a', 'STGI': 'a', 'REA Cyber City': 'a', 'Evalueserve India': 'a', 'Equiniti': 'a', 'Kissht': 'a', 'Makonis': 'a', 'Turabit LLC': 'a', 'Aratt Developers': 'a', 'Bloom Consulting Services, Inc.': 'a', 'PCS InfoTech': 'a', 'UNIQUECRYPTO GROUP': 'a', 'NeoLotex Business Solutions Private Limited': 'a', 'PW (PhysicsWallah)': 'a', 'Branch International': 'a', 'Sofomation': 'a', 'GEMRAJ TECHNOLOGIES LIMITED': 'a', 'Systellar Technologies': 'a', 'Pantheon Digital': 'a', 'VRIZE': 'a', 'Connecting Chains': 'a', 'Cyrino': 'a', 'Glorious Insight': 'a', 'Fleet Studio': 'a', 'CYAN360': 'a', 'Quantum Integrators': 'a', 'PDI Technologies': 'a', 'Zinnia': 'a', 'Squash Apps': 'a', 'TBH': 'a', 'ANS design house': 'a', 'SDLC Corp': 'a', 'TekDoors Inc.': 'a', 'SoftClouds': 'a', 'Bonzer Business Solutions Pvt. Ltd.': 'a', 'Techtinium': 'a', 'Control Z': 'a', 'Block Trix': 'a', 'Dot & Key Skincare': 'a', 'Smart Working': 'a', 'Hack2skill': 'a', 'FLYHIGH TRAVEL LIMITED': 'a', 'Mirchi': 'a', 'QAD': 'a', 'Chargebee': 'a', 'NIRU Group': 'a', 'Promaynov Advisory Services Pvt. Ltd': 'a', 'TAO The Automation Office': 'a', 'QualiZeal': 'a', 'Thryve Digital Health LLP': 'a', 'BIMstream': 'a', 'Reso': 'a', 'Amity University Jharkhand': 'a', 'Sensiple': 'a', 'Skuad: a Payoneer company': 'a', 'Convin': 'a', 'PedalStart': 'a', 'Phastar': 'a', 'Brim Labs': 'a', 'PureSoftware Ltd': 'a', 'TEKNIKOZ': 'a', 'The Family Office Company BSC (c)': 'a', 'Lo Foods': 'a', 'Qualhon Informatics Pvt. Ltd.': 'a', 'Knowbiliti': 'a', 'Adamas Tech Consulting': 'a', 'InfoGravity': 'a', 'HuntingCube Recruitment Solutions': 'a', 'NPS Prism': 'a', 'Space Matrix': 'a', 'Ambition': 'a', 'Fintech Global Center': 'a', 'Talent Sutra': 'a', 'IntegriChain': 'a', 'FPL Technologies': 'a', 'Staffing': 'a', '6thStreet.com': 'a', 'Workassist': 'a', 'Trianz': 'a', 'ThoughtFocus': 'a', 'Wing Assistant': 'a', 'Carillon Gaming': 'a', 'StatusNeo': 'a', 'Chinar Quantum AI': 'a', 'Trellance': 'a', 'eWorkplace Apps': 'a', 'DigitalBuzz': 'a', 'BEACH RESORT IN SOUTH GOA': 'a', 'Mirafra Technologies': 'a', 'Awign Expert': 'a', 'micro1': 'a', 'HeyCoach': 'a', 'Work Store Limited': 'a', 'SoftxAI Technology Private Limited - Software & AI Solutions': 'a', 'Inxite Out': 'a', 'Mitchell Martin Inc.': 'a', 'Deltacubes': 'a', 'Amrapali Solutions': 'a', 'Tarento Group': 'a', 'Aeris IoT SaaS': 'a', 'Intelgic': 'a'}
print(len(co))
# Out:
# 458

# %%
co={
  "MobiusEngine": "a",
  "Quidich Innovation Labs": "a",
  "YellowSquash": "a",
  "ChainThat Limited": "a",
  "QuillBot": "a",
  "Impetus": "a",
  "BeGig": "a",
  "tsworks": "a",
  "GlobalPros": "a",
  "iMerit Technology": "a",
  "Storable India": "a",
  "People Tech Group Inc": "a",
  "LENS Corporation": "a",
  "TrueFan": "a",
  "Crimson Energy Experts Pvt Ltd": "a",
  "Adept Global": "a",
  "Bellurbis": "a",
  "YO IT CONSULTING": "a",
  "XpertDox": "a",
  "MindBrain": "a",
  "CodeChavo": "a",
  "Lingaro": "a",
  "Discoveries Quintessential": "a",
  "LeadSoc Technologies Pvt Ltd": "a",
  "GoodEnough Energy": "a",
  "Renjoy": "a",
  "MINDTEL": "a",
  "Jivi AI": "a",
  "MachineHack Generative AI": "a",
  "Avataar": "a",
  "TerraGiG": "a",
  "BrickRed Systems": "a",
  "Innova ESI": "a",
  "Infinit-O": "a",
  "BLJ Tech Geeks": "a",
  "Gabit": "a",
  "True Tech Professionals": "a",
  "Azmarq Technovation Private Limited": "a",
  "Raphe mPhibr": "a",
  "Varahe Analytics Private Limited": "a",
  "CleanDirty": "a",
  "Quartic.ai": "a",
  "Flam": "a",
  "Beyond&More Design": "a",
  "Sigmoid": "a",
  "Setoo": "a",
  "Yubi": "a",
  "Credgenics": "a",
  "Vensure Employer Solutions": "a",
  "Mancer Consulting Services": "a",
  "Propellence Consulting": "a",
  "Precision AQ": "a",
  "Artmac": "a",
  "Elucidata": "a",
  "Geektrust": "a",
  "Cropin": "a",
  "Teamware Solutions": "a",
  "Webologix Ltd/ INC": "a",
  "Xemplar Insights": "a",
  "Reqpedia": "a",
  "FirstHive | Customer Data Platform": "a",
  "NEXA - Digital Marketing": "a",
  "Recro": "a",
  "Animaker Inc.": "a",
  "Staqu Technologies": "a",
  "Vistec Partners": "a",
  "SNP Technologies, Inc.": "a",
  "Grizmo Labs": "a",
  "MethodHub": "a",
  "ACL Digital": "a",
  "nerdAppLabs Software Solutions Private Limited": "a",
  "EverestDX Inc": "a",
  "IndoAI Technologies": "a",
  "Thriving Springs AI": "a",
  "Where U Elevate": "a",
  "MDI NetworX": "a",
  "Agilisium Consulting": "a",
  "ZeOmega": "a",
  "Cognida.ai": "a",
  "Zzazz": "a",
  "Digile": "a",
  "RiskInsight Consulting Pvt Ltd.": "a",
  "SuperAGI": "a",
  "MSRcosmos LLC": "a",
  "Sirius Digitech": "a",
  "Stealth AI Startup": "a",
  "iAcuity Fintech": "a",
  "Atyeti Inc": "a",
  "Tezo": "a",
  "Insightzz": "a",
  "Circuitry.ai": "a",
  "Onit India": "a",
  "Dexian India": "a",
  "Upsurge Labs": "a",
  "Solytics Partners": "a",
  "Mogi I/O : OTT/Podcast/Short Video Apps for you": "a",
  "Borneo": "a",
  "Aaizel International Technologies Pvt Ltd": "a",
  "Adagrad AI": "a",
  "Space Inventive": "a",
  "SWITRUS HOLIDAYS (P) LTD": "a",
  "Fizal Outsourcing": "a",
  "Relanto": "a",
  "Blackstraw": "a",
  "ChicMic Studios": "a",
  "Parsec Solutions LLC": "a",
  "Litmus7": "a",
  "Askme Technologies": "a",
  "Ekshvaku Tech Innovations": "a",
  "STARTWITH BASICX": "a",
  "Hireginie": "a",
  "Pronix Inc": "a",
  "SalesPanda": "a",
  "IntersectIQ": "a",
  "Redian Software Global": "a",
  "SmartQ": "a",
  "TekWissen India": "a",
  "Mopid": "a",
  "Quantzig": "a",
  "ThoughtsWin Systems": "a",
  "CistekAI": "a",
  "MindInventory": "a",
  "Terawe Corporation": "a",
  "Accellor": "a",
  "Anagh Technologies Inc": "a",
  "C5i": "a",
  "Implere Technologies Pvt Ltd": "a",
  "Relyance AI": "a",
  "GKM IT": "a",
  "Wissen Technology": "a",
  "Lorven Technologies Inc.": "a",
  "Akaike Technologies": "a",
  "Webority Technologies": "a",
  "QpiAI": "a",
  "HabileLabs": "a",
  "Prudent Technologies and Consulting, Inc.": "a",
  "Talentoj": "a",
  "Runo": "a",
  "Pixelo Digital": "a",
  "DeepConverse": "a",
  "SHIELD": "a",
  "Wisemonk": "a",
  "Xceedance": "a",
  "Straive": "a",
  "Ampstek": "a",
  "Huptech HR Solutions": "a",
  "Cozzera": "a",
  "Voya India": "a",
  "Techfastic": "a",
  "Ubique Systems": "a",
  "Virtana Corp.": "a",
  "RIAmetric": "a",
  "S P A Enterprise": "a",
  "Iffort": "a",
  "BlueOptima": "a",
  "Talentgigs": "a",
  "XopunTech (India) Pvt. Ltd.": "a",
  "Rayvector Technologies": "a",
  "ICS_Jobs": "a",
  "Resolink Technologies": "a",
  "VerticalServe": "a",
  "OpenCV University": "a",
  "Niqo Robotics": "a",
  "Metropolis Technologies": "a",
  "Natoe AI": "a",
  "Fulcrum Digital Inc": "a",
  "BJS Home Delivery": "a",
  "Taggd": "a",
  "Aindra Systems": "a",
  "Academian Inc": "a",
  "WINIX Technologies Pvt Ltd": "a",
  "Pro Integrate": "a",
  "MTPL": "a",
  "Blaize": "a",
  "OTA Innovations": "a",
  "MODELIA": "a",
  "AIRA Matrix Private Limited": "a",
  "GrowthPal": "a",
  "Deccan AI": "a",
  "Altimate AI": "a",
  "ConcertAI": "a",
  "CloudZenia": "a",
  "Visual AId": "a",
  "IDfy": "a",
  "Versai": "a",
  "Datacrew.ai": "a",
  "Iris Software Inc.": "a",
  "Teleglobal International": "a",
  "iO Associates - UK/EU": "a",
  "MaxisIT Inc.": "a",
  "Canterr, Inc.": "a",
  "Ouro": "a",
  "KnowDis AI": "a",
  "The Hird": "a",
  "Darner AI Innovations": "a",
  "mokSa.ai": "a",
  "Burhani - Managed IT Services": "a",
  "ATC": "a",
  "alphastream.ai": "a",
  "Jones RecruitZo": "a",
  "thinkbridge": "a",
  "Verticurl": "a",
  "Krutrim": "a",
  "Dola AI": "a",
  "Batish Technologies Pty Ltd": "a",
  "Norstella": "a",
  "MindBrain Foundation": "a",
  "VAYUZ Technologies": "a",
  "Eternal Robotics": "a",
  "Newpage Solutions": "a",
  "Intellias": "a",
  "Novamind Tech": "a",
  "Thrillophilia.com": "a",
  "PeopleStrong": "a",
  "Macr 2": "a",
  "Moneyview": "a",
  "Jupiter AI Labs ✔": "a",
  "Resource One IT Solutions": "a",
  "MobileAppDaily": "a",
  "Gameskraft": "a",
  "Optym": "a",
  "Nisieon": "a",
  "Marketopper Securities Pvt Ltd": "a",
  "Swift Strategic Solutions Inc": "a",
  "Mitra AI": "a",
  "Vrinsoft Technology Pvt. Ltd.": "a",
  "Crescent Techservices": "a",
  "Programming.com": "a",
  "AXISCADES": "a",
  "Highbrow Technology Inc": "a",
  "Applicantz": "a",
  "Intuition IT – Intuitive Technology Recruitment": "a",
  "mthree": "a",
  "Coffeee.io": "a",
  "JK Tech": "a",
  "Aditi Consulting": "a",
  "GEDU Services": "a",
  "Baya Systems": "a",
  "Brainy Neurals - AI Company": "a",
  "Flop Hero Development Pvt Ltd": "a",
  "Timely Find": "a",
  "LawSikho": "a",
  "Walker Digital Table Systems, LLC": "a",
  "TheRecAI": "a",
  "TAC Security": "a",
  "AIGist24": "a",
  "Real Time Data Services": "a",
  "Infotree Global Solutions": "a",
  "Live D365": "a",
  "Murally Creations Pvt Ltd": "a",
  "Zupee": "a",
  "InRhythm": "a",
  "IntuCloud": "a",
  "Zyoin Group": "a",
  "Airties": "a",
  "Rosemallow Technologies Pvt Ltd": "a",
  "Anlage Infotech (India) P Ltd": "a",
  "Prodapt": "a",
  "Allinnov Research and Development Private Limited, India": "a",
  "AiSensy": "a",
  "Naatscorp Private Limited": "a",
  "Find Next Hire": "a",
  "Visit Health": "a",
  "Distributed Energy": "a",
  "Space-O Technologies": "a",
  "Veramed": "a",
  "NuMinds AI": "a",
  "WalkingTree Technologies": "a",
  "Leinex Consulting": "a",
  "qode.world": "a",
  "SUPREM.club": "a",
  "Beinex": "a",
  "Talent500": "a",
  "Digital Honchos": "a",
  "SPT Labtech": "a",
  "Primathon": "a",
  "Trigent Software - Professional Services": "a",
  "t3 Strategic Partners": "a",
  "Vertisystem": "a",
  "Acorn Globus": "a",
  "ResourceTree Global Services Pvt Ltd.": "a",
  "Dautom": "a",
  "TIGI HR": "a",
  "Confidential": "a",
  "WIN Home Inspection": "a",
  "MetaModels.ai": "a",
  "Cableteque": "a",
  "Emory Technologies Inc": "a",
  "IntraEdge": "a",
  "K-RY Tech Advisory": "a",
  "White fox Designs LLP": "a",
  "Hectae Analytics and Software Solutions": "a",
  "Anubudh": "a",
  "Matillion": "a",
  "TMRW House of Brands": "a",
  "STGI": "a",
  "REA Cyber City": "a",
  "Kissht": "a",
  "Makonis": "a",
  "Turabit LLC": "a",
  "Aratt Developers": "a",
  "Bloom Consulting Services, Inc.": "a",
  "UNIQUECRYPTO GROUP": "a",
  "NeoLotex Business Solutions Private Limited": "a",
  "Sofomation": "a",
  "Systellar Technologies": "a",
  "Pantheon Digital": "a",
  "VRIZE": "a",
  "Connecting Chains": "a",
  "Cyrino": "a",
  "Glorious Insight": "a",
  "Fleet Studio": "a",
  "CYAN360": "a",
  "Quantum Integrators": "a",
  "PDI Technologies": "a",
  "Zinnia": "a",
  "Squash Apps": "a",
  "TBH": "a",
  "ANS design house": "a",
  "SDLC Corp": "a",
  "TekDoors Inc.": "a",
  "SoftClouds": "a",
  "Bonzer Business Solutions Pvt. Ltd.": "a",
  "Techtinium": "a",
  "Control Z": "a",
  "Block Trix": "a",
  "Dot & Key Skincare": "a",
  "Smart Working": "a",
  "Hack2skill": "a",
  "FLYHIGH TRAVEL LIMITED": "a",
  "Mirchi": "a",
  "NIRU Group": "a",
  "Promaynov Advisory Services Pvt. Ltd": "a",
  "TAO The Automation Office": "a",
  "QualiZeal": "a",
  "Thryve Digital Health LLP": "a",
  "BIMstream": "a",
  "Reso": "a",
  "Amity University Jharkhand": "a",
  "Sensiple": "a",
  "Convin": "a",
  "PedalStart": "a",
  "Phastar": "a",
  "Brim Labs": "a",
  "PureSoftware Ltd": "a",
  "TEKNIKOZ": "a",
  "The Family Office Company BSC (c)": "a",
  "Lo Foods": "a",
  "Qualhon Informatics Pvt. Ltd.": "a",
  "Knowbiliti": "a",
  "Adamas Tech Consulting": "a",
  "InfoGravity": "a",
  "HuntingCube Recruitment Solutions": "a",
  "NPS Prism": "a",
  "Space Matrix": "a",
  "Ambition": "a",
  "Fintech Global Center": "a",
  "Talent Sutra": "a",
  "IntegriChain": "a",
  "FPL Technologies": "a",
  "Staffing": "a",
  "6thStreet.com": "a",
  "Workassist": "a",
  "ThoughtFocus": "a",
  "Wing Assistant": "a",
  "Carillon Gaming": "a",
  "StatusNeo": "a",
  "Chinar Quantum AI": "a",
  "Trellance": "a",
  "eWorkplace Apps": "a",
  "DigitalBuzz": "a",
  "BEACH RESORT IN SOUTH GOA": "a",
  "Mirafra Technologies": "a",
  "Awign Expert": "a",
  "micro1": "a",
  "HeyCoach": "a",
  "Work Store Limited": "a",
  "SoftxAI Technology Private Limited - Software & AI Solutions": "a",
  "Inxite Out": "a",
  "Mitchell Martin Inc.": "a",
  "Deltacubes": "a",
  "Amrapali Solutions": "a",
  "Tarento Group": "a",
  "Aeris IoT SaaS": "a",
  "Intelgic": "a"
}


print(len(co))
# Out:
# 385

# %%
co={'Canopus Infosystems - A CMMI Level 3 Company': 'a', 'MobiusEngine': 'a', 'Trexquant Investment LP': 'a', 'Marx Enterprise Transformation Architecture': 'a', 'Quidich Innovation Labs': 'a', 'YellowSquash': 'a', 'ChainThat Limited': 'a', 'QuillBot': 'a', 'BeGig': 'a', 'tsworks': 'a', 'GlobalPros': 'a', 'iMerit Technology': 'a', 'Storable India': 'a', 'People Tech Group Inc': 'a', 'LENS Corporation': 'a', 'TrueFan': 'a', 'Crimson Energy Experts Pvt Ltd': 'a', 'Adept Global': 'a', 'Bellurbis': 'a', 'YO IT CONSULTING': 'a', 'XpertDox': 'a', 'MindBrain': 'a', 'CodeChavo': 'a', 'Lingaro': 'a', 'Discoveries Quintessential': 'a', 'LeadSoc Technologies Pvt Ltd': 'a', 'GoodEnough Energy': 'a', 'Renjoy': 'a', 'MINDTEL': 'a', 'Jivi AI': 'a', 'MachineHack Generative AI': 'a', 'Avataar': 'a', 'TerraGiG': 'a', 'BrickRed Systems': 'a', 'Innova ESI': 'a', 'Infinit-O': 'a', 'BLJ Tech Geeks': 'a', 'Gabit': 'a', 'Valiance Solutions': 'a', 'True Tech Professionals': 'a', 'Azmarq Technovation Private Limited': 'a', 'Raphe mPhibr': 'a', 'Varahe Analytics Private Limited': 'a', 'CleanDirty': 'a', 'Quartic.ai': 'a', 'Flam': 'a', 'Beyond&More Design': 'a', 'Sigmoid': 'a', 'Setoo': 'a', 'Credgenics': 'a', 'Vensure Employer Solutions': 'a', 'Mancer Consulting Services': 'a', 'Propellence Consulting': 'a', 'Precision AQ': 'a', 'Artmac': 'a', 'Elucidata': 'a', 'Geektrust': 'a', 'Cropin': 'a', 'Teamware Solutions': 'a', 'Webologix Ltd/ INC': 'a', 'Xemplar Insights': 'a', 'Reqpedia': 'a', 'FirstHive | Customer Data Platform': 'a', 'NEXA - Digital Marketing': 'a', 'Recro': 'a', 'Animaker Inc.': 'a', 'Staqu Technologies': 'a', 'Vistec Partners': 'a', 'SNP Technologies, Inc.': 'a', 'Grizmo Labs 🌐': 'a', 'MethodHub': 'a', 'nerdAppLabs Software Solutions Private Limited': 'a', 'EverestDX Inc': 'a', 'IndoAI Technologies': 'a', 'TIH | IIT Bombay': 'a', 'Thriving Springs AI': 'a', 'C3IT Solutions - A Saxon Company': 'a', 'gnani.ai': 'a', 'SLK': 'a', 'Where U Elevate': 'a', 'Xebia': 'a', 'MDI NetworX': 'a', 'Agilisium Consulting': 'a', 'ZeOmega': 'a', 'ZIGRAM': 'a', 'Cognida.ai': 'a', 'Zzazz': 'a', 'GyanSys Inc.': 'a', 'Marlabs Software Pvt Ltd': 'a', 'Deriv': 'a', 'Digile': 'a', 'RiskInsight Consulting Pvt Ltd.': 'a', 'SuperAGI': 'a', 'MSRcosmos LLC': 'a', 'Sirius Digitech': 'a', 'Stealth AI Startup': 'a', 'iAcuity Fintech': 'a', 'Atyeti Inc': 'a', 'Tezo': 'a', 'Insightzz': 'a', 'Circuitry.ai': 'a', 'Upsurge Labs': 'a', 'Borneo': 'a', 'Aaizel International Technologies Pvt Ltd': 'a', '': 'a', 'Adagrad AI': 'a', 'Space Inventive': 'a', 'SWITRUS HOLIDAYS (P) LTD': 'a', 'Fizal Outsourcing': 'a', 'Relanto': 'a', 'Blackstraw': 'a', 'ChicMic Studios': 'a', 'Mechsoft Digital Technologies Pvt. Ltd.': 'a', 'Sulekha': 'a', 'Parsec Solutions LLC': 'a', 'Litmus7': 'a', 'Askme Technologies': 'a', 'Ekshvaku Tech Innovations': 'a', 'STARTWITH BASICX': 'a', 'Hireginie': 'a', 'Pronix Inc': 'a', 'SalesPanda': 'a', 'IntersectIQ': 'a', 'Redian Software Global': 'a', 'SmartQ': 'a', 'TekWissen India': 'a', 'Mopid': 'a', 'Synechron Technologies Pvt. Ltd.': 'a', 'Outsourced': 'a', 'Quantzig': 'a', 'ThoughtsWin Systems': 'a', 'CistekAI': 'a', 'ESDS Software Solution Limited': 'a', 'MindInventory': 'a', 'Terawe Corporation': 'a', 'Anagh Technologies Inc': 'a', 'C5i': 'a', 'Implere Technologies Pvt Ltd': 'a', 'Relyance AI': 'a', 'GKM IT': 'a', 'Lorven Technologies Inc.': 'a', 'Akaike Technologies': 'a', 'Webority Technologies': 'a', 'QpiAI': 'a', 'HabileLabs': 'a', 'Prudent Technologies and Consulting, Inc.': 'a', 'Talentoj': 'a', 'Runo': 'a', 'Pixelo Digital': 'a', 'Spirent Communications': 'a', 'DeepConverse': 'a', 'SHIELD': 'a', 'Wisemonk': 'a', 'Xceedance': 'a', 'Straive': 'a', 'Ampstek': 'a', 'Quantiphi': 'a', 'Huptech HR Solutions': 'a', 'Cozzera': 'a', 'Techfastic': 'a', 'Ubique Systems': 'a', 'Virtana Corp.': 'a', 'RIAmetric': 'a', 'Glance': 'a', 'Chingari®': 'a', 'S P A Enterprise': 'a', 'Iffort': 'a', 'BlueOptima': 'a', 'Talentgigs': 'a', 'XopunTech (India) Pvt. Ltd.': 'a', 'Rayvector Technologies': 'a', 'ICS_Jobs': 'a', 'Resolink Technologies': 'a', 'VerticalServe': 'a', 'OpenCV University': 'a', 'Niqo Robotics': 'a', 'Metropolis Technologies': 'a', 'Natoe AI': 'a', 'Fulcrum Digital Inc': 'a', 'BJS Home Delivery': 'a', 'Tredence Inc.': 'a', 'Algonomy': 'a', 'Taggd': 'a', 'Aindra Systems': 'a', 'Academian Inc': 'a', 'WINIX Technologies Pvt Ltd': 'a', 'Pro Integrate': 'a', 'OTA Innovations': 'a', 'MODELIA': 'a', 'AIRA Matrix Private Limited': 'a', 'GrowthPal': 'a', 'Deccan AI': 'a', 'Altimate AI': 'a', 'CloudZenia': 'a', 'Visual AId': 'a', 'IDfy': 'a', 'Versai': 'a', 'Datacrew.ai': 'a', 'KLA': 'a', 'Instabase': 'a', 'Teleglobal International': 'a', 'Canterr, Inc.': 'a', 'Ouro': 'a', 'Aspect Software': 'a', 'KnowDis AI': 'a', 'Dozen Diamonds': 'a', 'RSD Bajaj Global Law Firm': 'a', 'VMock': 'a', 'Netradyne': 'a', 'The Hird': 'a', 'TEG Analytics': 'a', 'Darner AI Innovations': 'a', 'Soon to be named': 'a', 'mokSa.ai': 'a', 'Burhani - Managed IT Services': 'a', 'ATC': 'a', 'alphastream.ai': 'a', 'Jones RecruitZo': 'a', 'thinkbridge': 'a', 'Verticurl': 'a', 'Velotio Technologies': 'a', 'Krutrim': 'a', 'Dola AI': 'a', 'Batish Technologies Pty Ltd': 'a', 'Norstella': 'a', 'MindBrain Foundation': 'a', 'VAYUZ Technologies': 'a', 'Eternal Robotics': 'a', 'Newpage Solutions': 'a', 'Truelancer.com': 'a', 'Intellias': 'a', 'Novamind Tech': 'a', 'Grant Thornton Bharat LLP': 'a', 'Thrillophilia.com': 'a', 'Macr 2': 'a', 'Jupiter AI Labs ✔': 'a', 'Resource One IT Solutions': 'a', 'Insight Global': 'a', 'MobileApp':'a'}

print(len(co))
# Out:
# 239

# %%
print((len(co)),(len(ques)))
# Out:
# 385 164

# %%
ques={'Python': '4', 'PyTorch': '3', 'Generative AI': '3', 'Large Language Models': '3', 'Machine Tools': '2', 'Natural Language Processing': '3', 'IT Industry Experience': '5', 'Machine Learning': '3', 'SQL': '3', 'Cloud Platform': '2', 'Artificial Intelligence': '3', 'Current CTC (in Lakhs)': '14', 'Expected CTC (in Lakhs)': '18', 'Notice Period (days)': '30', 'Node.js': '2', 'C#': '1', 'PHP': '1', 'Amazon Web Services (AWS)': '2', 'Microsoft Azure': '2', 'Software Development': '4', 'Data Structures and Algorithms': '4', 'Microservices/Application Development': '3', 'Dev-Sec-Ops': '3', 'State-of-the-art Generative AI Models': '3', 'ML Infrastructure': '3', 'Technical Leadership': '3', 'JavaScript': '3', 'React.js': '1', 'Large Language Model Operations (LLMOps)': '2', 'Data Science Engineer Experience': '3', 'MongoDB': '3', 'DS Algorithms Experience': '5', 'Data Engineering': '4', 'AzureML/AzureAI or GCP Vertex AI': '3', 'Production-ready Python Code Development': '5', 'Azure Databricks': '3', 'C++': '3', 'Tableau': '3', 'Transformer Models': '3', 'Applied Machine Learning': '5', 'Post-degree Work Experience': '3', 'PySpark': '3', 'XML': '4', 'Django REST Framework': '3', 'System Architecture': '3', 'Apache Spark': '1', 'Scala': '4', 'MLOps': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '2', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5'}

# %%
ques={'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Years of work experience with data structures and algorithms': '4', 'Years of experience in Microservices or Application development': '3', 'Years of experience on Dev-Sec-Ops principles and practices': '3', 'Years of work experience with state-of-the-art Generative AI models': '3', 'Years of work experience with ML infrastructure': '3', 'Years of experience in a technical leadership role': '3', 'Years of work experience with JavaScript': '3', 'Years of work experience with React.js': '1', 'Years of work experience with Large Language Model Operations (LLMOps)': '2', 'Years of experience as a Data Science Engineer': '3', 'Years of experience with Mongo DB': '3', 'Years of experience working on DS ALGORITHMS': '5', 'Years of experience in Data Engineering': '4', 'Years of experience with AzureML/AzureAI or GCP Vertex AI': '3', 'Years of experience in production ready Python code development': '5', 'Years of experience in Azure Databricks': '3', 'How soon can you join?': '30', 'Years of work experience with C++': '3', 'Years of work experience with Tableau': '3', 'Years of work experience with Transformer Models': '3', 'Years of work experience with Applied Machine Learning': '5', 'Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)': '3', 'Years of work experience with PySpark': '3', 'Years of work experience with XML': '4', 'Years of full-time experience': '5', 'Years of work experience with Django REST Framework': '3', 'Years of work experience with System Architecture': '3', 'Years of work experience with Data Structures': '4', 'Years of work experience with Apache Spark': '1', 'Years of work experience with Scala': '4', 'Relevant Experience in MLOPS': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '4', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5', 'We must fill this position urgently. Can you start immediately? Please mention your Notice Period In days': '14', 'How many years of work experience do you have with Amazon S3?': '3', 'How many years of work experience do you have with AIML?': '14', 'How many years of Consulting experience do you currently have?': '1', 'How many years of work experience do you have with DevOps?': '3', 'Years of experience in NLP and Deep Leaning?': '3', 'How many years of work experience do you have with Data Science?': '3', 'How many years of experience do you have working directly with LLMs or NLP models?': '3', 'How many years of experience do you have with Python for Computer Vision tasks?': '14', 'How many years of work experience do you have with Chatbot Development?': '2', 'How many years of work experience do you have with Databases?': '4', 'How many years of work experience do you have with AI/ML?': '3', 'How many years of work experience do you have with Deep Learning?': '3', 'What is your Whatsapp number?': '8077975459', 'How many years of work experience do you have with UiPath?': '3', 'How many years of work experience do you have with Django?': '3', 'How many years of work experience do you have with Java?': '2', 'How many years of work experience do you have with Design Patterns?': '3', 'How many years of experience do you have in Azure Data Factory': '2', 'How many years of experience do you have in Azure Kubernetes Service': '2', 'How many years of experience do you have in Python, R, or C#?': '4', 'How many years of work experience do you have with Azure Synapse Analytics': '2', 'How many years of work experience do you have with AWS SageMaker?': '3', 'Current CTC (Enter full number)': '14', 'Do you have any offers in Hand? If yes mention the number': '1', 'How many years of work experience do you have with Data Analytics?': '3', 'How many years of work experience do you have with Database Management System (DBMS)?': '4', 'How many engineers or team members have you directly managed in your previous roles?': '10', 'How many years of work experience do you have with springboot?': '2', 'How many years of experience you have as an Engineering Maanger?': '4', 'How many years of work experience do you have with Test Automation Tools?': '14', 'How many years of work experience do you have with Machine Learning Algorithms?': '3', 'How many years of experience you have as a Data Scientist in CPG domain?': '1', 'How many years of experience you have for Market mix modelling?': '1', 'How many years of work experience do you have with Technical Architecture?': '2', 'How many years of experience do you have in information retrieval?': '3', 'How many years of experience do you have with Heuristics/Meta-Heuristics?': '1', 'How many years of experience as an ETL Developer?': '3', "How many years of work experience do you have with Azure's durable function?": '2', 'How many years of work experience do you have with Fivetran?': '1', 'How many years of work experience do you have with Software Architecture?': '3', 'How many years of work experience do you have with FastAPI?': '2', 'How many years of work experience do you have with Twilio?': '1', 'How many years of work experience do you have with TTS?': '3', 'What’s your experience with agent-based LLM chains?': '3', 'Expected in hand salary?': '5', 'How many years of work experience do you have with Flask?': '3', 'How many years of work experience do you have with Jenkins?': '2', 'How many years of work experience do you have with Microsoft Excel?': '3', 'How many years of work experience do you have with Spring Framework?': '2', 'How many years of work experience do you have with Apache?': '2', 'Proficiency in Python and the ability to write a small piece of code.': '4', 'How many years of work experience do you have with Client Communication?': '3', 'How many years of work experience do you have with pytest?': '3', 'How many years of work experience do you have with Data Validation?': '3', 'How many years of work experience do you have with API Testing?': '2', 'How many years of work experience do you have with Python Automation?': '4', 'Expected CTC? Apply only if its below 9lpa': '18', 'How many years of work experience do you have with TypeScript?': '2', 'LinkedIn Profile': 'vashisth malik', 'Website': '""', 'How many years of experience do you have working on server side software (backend)?': '4', 'How many years of experience you have in developing on Linux? Additionally, are you proficient in Linux and its command-line tools? If you have utilized Linux command-line tools in your projects, could you elaborate on the tasks you performed using them?': '2', 'Which scripting languages are you proficient in? (Python is preferred, but Bash is also acceptable.)': '3', 'If a SoundHound employee referred you to this job, please provide their name and the context in which you know each other.': 'na', 'How many years of work experience do you have with Selenium?': '4', 'What is your current monthly salary?': '14', 'How many years of experience do you have in training/teaching data science?': '4', 'What is your expectation in terms of (Gross) Per Month Salary': '18', 'How many years of work experience do you have as a Javascript Fullstack Developer?': '14', 'How many years of work experience do you have with Unix?': 'q', 'How many years of work experience do you have with Linux?': '3', 'How many years of work experience do you have with CDISC Standards?': '1', 'If Yes to above, please provide details - Name of Tesco Entity you worked for, Employee Serial Number, Tenure ( From To), Location of employment': 'na', 'If you select Other in the above question, please state what eligibility you have to work in India': 'na', 'Your message to the hiring manager': 'na', 'What is your current location?': 'meerut', 'Reason for change?': 'na', 'What primary technologies have you used or experienced in?': '4', 'What is your minimum annual Salary expectation (Base/Fixed) ?': '14', 'How many years of work experience do you have with Atlas?': '0', 'What are your salary expectations?': '18', 'How many years of work experience do you have with MySQL?': '1', 'How many experience do you have in Golang': '14', 'What is your Expected Annual Salary ?': '18', 'How many years of experience you have into software design and programming?': '5', 'How many years of experience do you have in model development?': '3', 'Name as per Pan Card': 'vashisht malik', 'What are your main technical skills?': 'python', 'How many years of work experience do you have with ASP.NET Core?': '3', 'Relevant experience as a Technical Architect': '2'}

# %%
print(ques)
# Out:
# {'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Yea
# ...

# %%
co={}

# %%
model = genai.GenerativeModel("gemini-1.5-pro-latest")

# %%
result = model.generate_content(
    f"Use this Dictionary schema:{ques} and answer How many years of work experience do you have with Data Mining? question. Give the output in 1 word(in Integer format) only, if no answer is found in dictionary than output 9. Strictly use response schema for output",
    generation_config=genai.GenerationConfig(
        response_mime_type="application/json", response_schema=int
    ),
    )

print(result.text)
# Out:
# 9

# %%
ques={'Years of work experience with Python': '4', 'Years of work experience with PyTorch': '3', 'Years of work experience with Generative AI': '3', 'Years of work experience with Large Language Models (LLM)': '3', 'Years of work experience with Machine Tools': '2', 'Years of work experience with Natural Language Processing (NLP)': '3', 'Overall IT Industry Experience': '5', 'Years of work experience with Machine Learning': '3', 'Years of experience in SQL': '3', 'Years of experience in Cloud platform': '2', 'Years of work experience with Artificial Intelligence (AI)': '3', 'Current CTC (LPA)': '14', 'Expected CTC (LPA)': '18', 'Notice Period (days)': '30', 'Years of work experience with Node.js': '2', 'Total Years of Experience': '5', 'Years of work experience with C#': '1', 'Years of work experience with PHP': '1', 'Years of work experience with Amazon Web Services (AWS)': '2', 'Years of work experience with Microsoft Azure': '2', 'Years of experience in software development': '4', 'Years of work experience with data structures and algorithms': '4', 'Years of experience in Microservices or Application development': '3', 'Years of experience on Dev-Sec-Ops principles and practices': '3', 'Years of work experience with state-of-the-art Generative AI models': '3', 'Years of work experience with ML infrastructure': '3', 'Years of experience in a technical leadership role': '3', 'Years of work experience with JavaScript': '3', 'Years of work experience with React.js': '1', 'Years of work experience with Large Language Model Operations (LLMOps)': '2', 'Years of experience as a Data Science Engineer': '3', 'Years of experience with Mongo DB': '3', 'Years of experience working on DS ALGORITHMS': '5', 'Years of experience in Data Engineering': '4', 'Years of experience with AzureML/AzureAI or GCP Vertex AI': '3', 'Years of experience in production ready Python code development': '5', 'Years of experience in Azure Databricks': '3', 'How soon can you join?': '30', 'Years of work experience with C++': '3', 'Years of work experience with Tableau': '3', 'Years of work experience with Transformer Models': '3', 'Years of work experience with Applied Machine Learning': '5', 'Overall Years of Work Experience (post B.E/B.Tech/M.E/M.Tech/Master of Science)': '3', 'Years of work experience with PySpark': '3', 'Years of work experience with XML': '4', 'Years of full-time experience': '5', 'Years of work experience with Django REST Framework': '3', 'Years of work experience with System Architecture': '3', 'Years of work experience with Data Structures': '4', 'Years of work experience with Apache Spark': '1', 'Years of work experience with Scala': '4', 'Relevant Experience in MLOPS': '2', 'In how many days you can join?': '30', 'How many years of work experience do you have with Data Engineering?': '3', 'How many years of work experience do you have with ClickHouse?': '1', 'How many years of work experience do you have with Extract, Transform, Load (ETL)?': '14', 'How many years of work experience do you have in AWS/GCP/Azure?': '3', 'How many years of work experience do you have in relational database (RDBMS)?': '3', 'How many years of work experience do you have in web technologies?': '3', 'How many years of work experience do you have with Python (Programming Language)?': '4', 'How many years of work experience do you have with AWS Lambda?': '3', 'Are you good at writing unit tests and debug scripts to ensure the quality and reliability of the code?': 'good', 'How many years of work experience do you have with LLM?': '3', 'How many years of work experience do you have with Troubleshooting and debugging of code?': '3', 'How many years of Technology, Information and Internet experience do you currently have?': '5', 'How many years of work experience do you have with Software as a Service (SaaS)?': '5', 'How many years of work experience do you have with TensorFlow?': '4', 'How many years of work experience do you have with Image Processing?': '3', 'How many years of work experience do you have with Computer Vision?': '3', 'How many years of work experience do you have in Networking concepts and protocols ?': '5', 'how many years have you worked in a product based company ?': '4', 'How many years of work experience do you have with Snowflake?': '4', 'How many years of work experience do you have with Neural Networks?': '5', 'We must fill this position urgently. Can you start immediately? Please mention your Notice Period In days': '14', 'How many years of work experience do you have with Amazon S3?': '3', 'How many years of work experience do you have with AIML?': '14', 'How many years of Consulting experience do you currently have?': '1', 'How many years of work experience do you have with DevOps?': '3', 'Years of experience in NLP and Deep Leaning?': '3', 'How many years of work experience do you have with Data Science?': '3', 'How many years of experience do you have working directly with LLMs or NLP models?': '3', 'How many years of experience do you have with Python for Computer Vision tasks?': '14', 'How many years of work experience do you have with Chatbot Development?': '2', 'How many years of work experience do you have with Databases?': '4', 'How many years of work experience do you have with AI/ML?': '3', 'How many years of work experience do you have with Deep Learning?': '3', 'What is your Whatsapp number?': '8077975459', 'How many years of work experience do you have with UiPath?': '3', 'How many years of work experience do you have with Django?': '3', 'How many years of work experience do you have with Java?': '2', 'How many years of work experience do you have with Design Patterns?': '3', 'How many years of experience do you have in Azure Data Factory': '2', 'How many years of experience do you have in Azure Kubernetes Service': '2', 'How many years of experience do you have in Python, R, or C#?': '4', 'How many years of work experience do you have with Azure Synapse Analytics': '2', 'How many years of work experience do you have with AWS SageMaker?': '3', 'Current CTC (Enter full number)': '14', 'Do you have any offers in Hand? If yes mention the number': '1', 'How many years of work experience do you have with Data Analytics?': '3', 'How many years of work experience do you have with Database Management System (DBMS)?': '4', 'How many engineers or team members have you directly managed in your previous roles?': '10', 'How many years of work experience do you have with springboot?': '2', 'How many years of experience you have as an Engineering Maanger?': '4', 'How many years of work experience do you have with Test Automation Tools?': '14', 'How many years of work experience do you have with Machine Learning Algorithms?': '3', 'How many years of experience you have as a Data Scientist in CPG domain?': '1', 'How many years of experience you have for Market mix modelling?': '1', 'How many years of work experience do you have with Technical Architecture?': '2', 'How many years of experience do you have in information retrieval?': '3', 'How many years of experience do you have with Heuristics/Meta-Heuristics?': '1', 'How many years of experience as an ETL Developer?': '3', "How many years of work experience do you have with Azure's durable function?": '2', 'How many years of work experience do you have with Fivetran?': '1', 'How many years of work experience do you have with Software Architecture?': '3', 'How many years of work experience do you have with FastAPI?': '2', 'How many years of work experience do you have with Twilio?': '1', 'How many years of work experience do you have with TTS?': '3', 'What’s your experience with agent-based LLM chains?': '3', 'Expected in hand salary?': '5', 'How many years of work experience do you have with Flask?': '3', 'How many years of work experience do you have with Jenkins?': '2', 'How many years of work experience do you have with Microsoft Excel?': '3', 'How many years of work experience do you have with Spring Framework?': '2', 'How many years of work experience do you have with Apache?': '2', 'Proficiency in Python and the ability to write a small piece of code.': '4', 'How many years of work experience do you have with Client Communication?': '3', 'How many years of work experience do you have with pytest?': '3', 'How many years of work experience do you have with Data Validation?': '3', 'How many years of work experience do you have with API Testing?': '2', 'How many years of work experience do you have with Python Automation?': '4', 'Expected CTC? Apply only if its below 9lpa': '18', 'How many years of work experience do you have with TypeScript?': '2', 'LinkedIn Profile': 'vashisth malik', 'Website': '""', 'How many years of experience do you have working on server side software (backend)?': '4', 'How many years of experience you have in developing on Linux? Additionally, are you proficient in Linux and its command-line tools? If you have utilized Linux command-line tools in your projects, could you elaborate on the tasks you performed using them?': '2', 'Which scripting languages are you proficient in? (Python is preferred, but Bash is also acceptable.)': '3', 'If a SoundHound employee referred you to this job, please provide their name and the context in which you know each other.': 'na', 'How many years of work experience do you have with Selenium?': '4', 'What is your current monthly salary?': '14', 'How many years of experience do you have in training/teaching data science?': '4', 'What is your expectation in terms of (Gross) Per Month Salary': '18', 'How many years of work experience do you have as a Javascript Fullstack Developer?': '14', 'How many years of work experience do you have with Unix?': 'q', 'How many years of work experience do you have with Linux?': '3', 'How many years of work experience do you have with CDISC Standards?': '1', 'If Yes to above, please provide details - Name of Tesco Entity you worked for, Employee Serial Number, Tenure ( From To), Location of employment': 'na', 'If you select Other in the above question, please state what eligibility you have to work in India': 'na', 'Your message to the hiring manager': 'na', 'What is your current location?': 'meerut', 'Reason for change?': 'na', 'What primary technologies have you used or experienced in?': '4', 'What is your minimum annual Salary expectation (Base/Fixed) ?': '14', 'How many years of work experience do you have with Atlas?': '0', 'What are your salary expectations?': '18', 'How many years of work experience do you have with MySQL?': '1', 'How many experience do you have in Golang': '14', 'What is your Expected Annual Salary ?': '18', 'How many years of experience you have into software design and programming?': '5', 'How many years of experience do you have in model development?': '3', 'Name as per Pan Card': 'vashisht malik', 'What are your main technical skills?': 'python', 'How many years of work experience do you have with ASP.NET Core?': '3', 'Relevant experience as a Technical Architect': '2'}

# %%
# !node --inspect-brk puppeteer_code.js
# Out:
# 1538.45s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Debugger listening on ws://127.0.0.1:9229/56300aed-34ee-48a1-8593-cc226b620bc2
# For help, see: https://nodejs.org/en/docs/inspector
# Debugger attached.
# Waiting for the debugger to disconnect...
# file:///Users/sakshimalik/puppeteer_code.js:11
# import * as puppeteer from "puppeteer";
# ^^^^^^^^^^^^^^^^^^^^^
#
# SyntaxError: Identifier 'puppeteer' has already been declared
#     at compileSourceTextModule (node:internal/modules/esm/utils:338:16)
#     at ModuleLoader.moduleStrategy (node:internal/modules/esm/translators:106:18)
#     at #translate (node:internal/modules/esm/loader:470:12)
#     at ModuleLoader.loadAndTranslate (node:internal/modules/esm/loader:517:27)
#     at async ModuleJob._link (node:internal/modules/esm/module_job:115:19)
#
# Node.js v23.6.1

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
import json

def execute_puppeteer_in_selenium(selenium_driver, puppeteer_js_code):
    """
    Executes provided Puppeteer JS code within the Selenium-controlled browser.

    Args:
        selenium_driver: A Selenium webdriver instance.
        puppeteer_js_code: A string containing your Puppeteer JavaScript code.

    Returns:
        The output of your puppeteer js code in a dict.
    """
    # Construct the execution code.
    injection_script = f"""
        async function runPuppeteerCode() {{
            try {{
              {puppeteer_js_code}; // Your Puppeteer code from recorder with slight modifications
            // the return result should also be serialized as JSON so that python can consume it easily.
              return JSON.stringify(result);
            }} catch (error) {{
              return JSON.stringify({{ "error": error.message }});
            }}
        }}
        return runPuppeteerCode();
    """
    result = selenium_driver.execute_script(injection_script)
    return json.loads(result)

# --- Example Usage ---
# In Jupyter Notebook/Lab, we don't need the `if __name__ == '__main__':` check

# Set up Selenium (example with Chrome)
chrome_options = Options()
chrome_options.add_argument("--headless=new")

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options = chrome_options)


# Example URL (replace with your desired starting page)
driver.get("https://example.com")


# Sample Puppeteer code from devtools recorder (replace with your actual code), with modification to make it work inside the browser.
puppeteer_code = """
    const result = {};
    result.title = document.title;
    result.url = document.URL;
"""
puppeteer_output = execute_puppeteer_in_selenium(driver, puppeteer_code)
print("Output from Puppeteer Code:", puppeteer_output)


# More selenium interactions if needed


driver.quit()

# %%
import time,math,random,os
import utils,constants,config

from selenium import webdriver
from selenium.webdriver.common.by import By
from utils import prRed,prYellow,prGreen

from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService

class Linkedin:
    def __init__(self):

            prYellow("🌐 Bot will run in Chrome browser and log in Linkedin for you.")
            self.driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()),options=utils.chromeBrowserOptions())
            self.driver.get("https://www.linkedin.com/login?trk=guest_homepage-basic_nav-header-signin")

            prYellow("🔄 Trying to log in linkedin...")
            try:
                self.driver.find_element("id","username").send_keys('maliksakshi248@gmail.com')
                time.sleep(2)
                self.driver.find_element("id","password").send_keys('malik123@')
                time.sleep(2)
                self.driver.find_element("xpath",'//button[@type="submit"]').click()
                time.sleep(5)
                self.mongoConnection("Check")
            except:
                prRed("❌ Couldn't log in Linkedin by using Chrome. Please check your Linkedin credentials on config files line 7 and 8. If error continue you can define Chrome profile or run the bot on Firefox")



    def generateUrls(self):
        if not os.path.exists('data'):
            os.makedirs('data')
        try:
            with open('data/urlData.txt', 'w',encoding="utf-8" ) as file:
                linkedinJobLinks = utils.LinkedinUrlGenerate().generateUrlLinks()
                for url in linkedinJobLinks:
                    file.write(url+ "\n")
            prGreen("✅ Urls are created successfully, now the bot will visit those urls.")
        except:
            prRed("❌ Couldn't generate url, make sure you have /data folder and modified config.py file for your preferances.")

    def linkJobApply(self):
        self.generateUrls()
        countApplied = 0
        countJobs = 0

        urlData = utils.getUrlDataFile()

        for url in urlData:
            self.driver.get(url)

            totalJobs = self.driver.find_element(By.XPATH,'//small').text
            totalPages = utils.jobsToPages(totalJobs)

            urlWords =  utils.urlToKeywords(url)
            lineToWrite = "\n Category: " + urlWords[0] + ", Location: " +urlWords[1] + ", Applying " +str(totalJobs)+ " jobs."
            self.displayWriteResults(lineToWrite)

            for page in range(totalPages):
                currentPageJobs = constants.jobsPerPage * page
                url = url +"&start="+ str(currentPageJobs)
                self.driver.get(url)
                time.sleep(random.uniform(1, constants.botSpeed))

                offersPerPage = self.driver.find_elements(By.XPATH,'//li[@data-occludable-job-id]')
                offerIds = []

                time.sleep(random.uniform(1, constants.botSpeed))

                for offer in offersPerPage:
                    offerId = offer.get_attribute("data-occludable-job-id")
                    offerIds.append(int(offerId.split(":")[-1]))

                for jobID in offerIds:
                    offerPage = 'https://www.linkedin.com/jobs/view/' + str(jobID)
                    self.driver.get(offerPage)
                    time.sleep(random.uniform(1, constants.botSpeed))

                    countJobs += 1

                    jobProperties = self.getJobProperties(countJobs)
                    if "blacklisted" in jobProperties:
                        lineToWrite = jobProperties + " | " + "* 🤬 Blacklisted Job, skipped!: " +str(offerPage)
                        self.displayWriteResults(lineToWrite)

                    else :
                        button = self.easyApplyButton()

                        if button is not False:
                            button.click()
                            time.sleep(random.uniform(1, constants.botSpeed))
                            countApplied += 1
                            try:
                                self.chooseResume()
                                self.driver.find_element(By.CSS_SELECTOR, "button[aria-label='Submit application']").click()
                                time.sleep(random.uniform(1, constants.botSpeed))

                                lineToWrite = jobProperties + " | " + "* 🥳 Just Applied to this job: "  +str(offerPage)
                                self.displayWriteResults(lineToWrite)

                            except:
                                try:
                                    self.driver.find_element(By.CSS_SELECTOR,"button[aria-label='Continue to next step']").click()
                                    time.sleep(random.uniform(1, constants.botSpeed))

                                    comPercentage = self.driver.find_element(By.XPATH,'html/body/div[3]/div/div/div[2]/div/div/span').text
                                    percenNumber = int(comPercentage[0:comPercentage.index("%")])
                                    result = self.applyProcess(percenNumber,offerPage)
                                    lineToWrite = jobProperties + " | " + result
                                    self.displayWriteResults(lineToWrite)

                                except Exception as e:
                                    self.chooseResume()
                                    lineToWrite = jobProperties + " | " + "* 🥵 Cannot apply to this Job! " +str(offerPage)
                                    self.displayWriteResults(lineToWrite)
                        else:
                            lineToWrite = jobProperties + " | " + "* 🥳 Already applied! Job: " +str(offerPage)
                            self.displayWriteResults(lineToWrite)


            prYellow("Category: " + urlWords[0] + "," +urlWords[1]+ " applied: " + str(countApplied) +
                  " jobs out of " + str(countJobs) + ".")

        utils.donate(self)

    def chooseResume(self):
        try:
            beSureIncludeResumeTxt = self.driver.find_element(By.CLASS_NAME, "jobs-document-upload__title--is-required")
            if(beSureIncludeResumeTxt.text == "Be sure to include an updated resume"):
                resumes = self.driver.find_elements(By.CSS_SELECTOR,"button[aria-label='Choose Resume']")
                if(len(resumes) == 1):
                    resumes[0].click()
                elif(len(resumes)>1):
                    resumes[config.preferredCv-1].click()
                else:
                    prRed("❌ No resume has been selected please add at least one resume to your Linkedin account.")
        except:
            pass

    def getJobProperties(self, count):
        textToWrite = ""
        jobTitle = ""
        jobCompany = ""
        jobLocation = ""
        jobWOrkPlace = ""
        jobPostedDate = ""
        jobApplications = ""

        try:
            jobTitle = self.driver.find_element(By.XPATH,"//h1[contains(@class, 'job-title')]").get_attribute("innerHTML").strip()
            res = [blItem for blItem in config.blackListTitles if(blItem.lower() in jobTitle.lower())]
            if (len(res)>0):
                jobTitle += "(blacklisted title: "+ ' '.join(res)+ ")"
        except Exception as e:
            if(config.displayWarnings):
                prYellow("⚠️ Warning in getting jobTitle: " +str(e)[0:50])
            jobTitle = ""

        try:
            jobCompany = self.driver.find_element(By.XPATH,"//a[contains(@class, 'ember-view t-black t-normal')]").get_attribute("innerHTML").strip()
            res = [blItem for blItem in config.blacklistCompanies if(blItem.lower() in jobTitle.lower())]
            if (len(res)>0):
                jobCompany += "(blacklisted company: "+ ' '.join(res)+ ")"
        except Exception as e:
            if(config.displayWarnings):
                prYellow("⚠️ Warning in getting jobCompany: " +str(e)[0:50])
            jobCompany = ""

        try:
            jobLocation = self.driver.find_element(By.XPATH,"//span[contains(@class, 'bullet')]").get_attribute("innerHTML").strip()
        except Exception as e:
            if(config.displayWarnings):
                prYellow("⚠️ Warning in getting jobLocation: " +str(e)[0:50])
            jobLocation = ""

        try:
            jobWOrkPlace = self.driver.find_element(By.XPATH,"//span[contains(@class, 'workplace-type')]").get_attribute("innerHTML").strip()
        except Exception as e:
            if(config.displayWarnings):
                prYellow("⚠️ Warning in getting jobWorkPlace: " +str(e)[0:50])
            jobWOrkPlace = ""

        try:
            jobPostedDate = self.driver.find_element(By.XPATH,"//span[contains(@class, 'posted-date')]").get_attribute("innerHTML").strip()
        except Exception as e:
            if(config.displayWarnings):
                prYellow("⚠️ Warning in getting jobPostedDate: " +str(e)[0:50])
            jobPostedDate = ""

        try:
            jobApplications= self.driver.find_element(By.XPATH,"//span[contains(@class, 'applicant-count')]").get_attribute("innerHTML").strip()
        except Exception as e:
            if(config.displayWarnings):
                prYellow("⚠️ Warning in getting jobApplications: " +str(e)[0:50])
            jobApplications = ""

        textToWrite = str(count)+ " | " +jobTitle+  " | " +jobCompany+  " | "  +jobLocation+ " | "  +jobWOrkPlace+ " | " +jobPostedDate+ " | " +jobApplications
        return textToWrite

    def easyApplyButton(self):
        try:
            time.sleep(random.uniform(1, constants.botSpeed))
            button = self.driver.find_element(By.XPATH,
                '//button[contains(@class, "jobs-apply-button")]')
            EasyApplyButton = button
        except:
            EasyApplyButton = False

        return EasyApplyButton

    def applyProcess(self, percentage, offerPage):
        applyPages = math.floor(100 / percentage)
        result = ""
        try:
            for pages in range(applyPages-2):
                self.driver.find_element(By.CSS_SELECTOR,"button[aria-label='Continue to next step']").click()
                time.sleep(random.uniform(1, constants.botSpeed))

            self.driver.find_element(By.CSS_SELECTOR,"button[aria-label='Review your application']").click()
            time.sleep(random.uniform(1, constants.botSpeed))

            if config.followCompanies is False:
                self.driver.find_element(By.CSS_SELECTOR,"label[for='follow-company-checkbox']").click()
                time.sleep(random.uniform(1, constants.botSpeed))

            self.driver.find_element(By.CSS_SELECTOR,"button[aria-label='Submit application']").click()
            time.sleep(random.uniform(1, constants.botSpeed))

            result = "* 🥳 Just Applied to this job: " +str(offerPage)
        except:
            # PRO FEATURE! OUTPUT UNANSWERED QUESTIONS, APPLY THEM VIA OPENAI, output them.
            result = "* 🥵 " +str(applyPages)+ " Pages, couldn't apply to this job! Extra info needed. Link: " +str(offerPage)
        return result

    def displayWriteResults(self,lineToWrite: str):
        try:
            print(lineToWrite)
            utils.writeResults(lineToWrite)
        except Exception as e:
            prRed("❌ Error in DisplayWriteResults: " +str(e))

start = time.time()
Linkedin().linkJobApply()
end = time.time()
prYellow("---Took: " + str(round((time.time() - start)/60)) + " minute(s).")
